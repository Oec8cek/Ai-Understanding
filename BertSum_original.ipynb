# %% [markdown]
# <a href="https://colab.research.google.com/github/Oec8cek/Ai-Understanding/blob/main/BertSum_original.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colab에서 Mecab 설치

# %%
## 1. mecab-ko 설치

# !wget https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# !tar xvfz mecab-0.996-ko-0.9.2.tar.gz
# %cd mecab-0.996-ko-0.9.2
# !./configure
# !make
# !make check
# !sudo make install

# %%
# !ldconfig
# Out:
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link

# %%
## 2. mecab-dic 설치

# !wget https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# !tar xvfz mecab-ko-dic-2.1.1-20180720.tar.gz
# !cd mecab-ko-dic-2.1.1-20180720
# !./configure
# !make
# !sudo make install
#출처: https://jongsky.tistory.com/30 [시간의 농도:티스토리]
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# --2024-02-09 03:21:12--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22c0:3470
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNOAB6267T&Signature=OLvxm%2B6kmN0f0ha8jqSr%2F9iC%2FiY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEDQaCXVzLWVhc3QtMSJGMEQCIAIGL19mAeAh%2BY5nkToBdyPTC13TcGH8RFtSu1Qv4AKrAiBVaYnJNTP4q7d5dFb7FgzqxLgNSJHdafMm56FJvIZffyqwAgj8%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDk4NDUyNTEwMTE0NiIMotXIFawQuGYpxN2SKoQCtc4xTz3YEEcdCqyTd8RbpShT8naFdnAahZ8nEhjWkb5SVIEQlPe8D7rg2KJU2TrML3P4TCvEU9IFI3KlF%2Bi3OTIwdI1VNCJ7e0h3HUw8iAIIgWiA1mgfAUtsbk02OuRQsYQRjYAH0JGq16dffoImuI%2BO0OVbKX1rpBeyu%2F0iMCMMybfcvhzXzQH6DZPJgHcviSME9M2T45kc%2BpsVFV2rlD9L3mQpSpZvm%2BXUu5cyBXL%2F8GdT09y%2B4KSASQbDuCgQsvQ0yMxku6Eas%2FbjCud%2B7RYR6rDly3N59I4X4x4DWDKLYriAAcIWTGN%2B4MZCYBRHNgOjGnkmgcTrgK6CGx2j%2BhLE31UwqbSWrgY6ngGdEoaBlNF2C%2BS8tuoMV1i8gjLY8swOGyJ3pTPJ1RXkiIh7ltbF33%2F9b4yvqCoUuU7ClpcfQxoClJAeGUBCSg14yYzkBycl%2FgThA15qk%2F32f7a1c3jLFcKwartfHWNC%2FKiGL4kBWATPBHmQu5C74w5QDuk6IHJXfBv33nCBKq%2BXZ7M0z40f4xvxEAaeUo2XzdnawPV7knCx726TkdsprQ%3D%3D&Expires=1707450673 [following]
# --2024-02-09 03:21:13--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNOAB6267T&Signature=OLvxm%2B6kmN0f0ha8jqSr%2F9iC%2FiY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEDQaCXVzLWVhc3QtMSJGMEQCIAIGL19mAeAh%2BY5nkToBdyPTC13TcGH8RFtSu1Qv4AKrAiBVaYnJNTP4q7d5dFb7FgzqxLgNSJHdafMm56FJvIZffyqwAgj8%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDk4NDUyNTEwMTE0NiIMotXIFawQuGYpxN2SKoQCtc4xTz3YEEcdCqyTd8RbpShT8naFdnAahZ8nEhjWkb5SVIEQlPe8D7rg2KJU2TrML3P4TCvEU9IFI3KlF%2Bi3OTIwdI1VNCJ7e0h3HUw8iAIIgWiA1mgfAUtsbk02OuRQsYQRjYAH0JGq16dffoImuI%2BO0OVbKX1rpBeyu%2F0iMCMMybfcvhzXzQH6DZPJgHcviSME9M2T45kc%2BpsVFV2rlD9L3mQpSpZvm%2BXUu5cyBXL%2F8GdT09y%2B4KSASQbDuCgQsvQ0yMxku6Eas%2FbjCud%2B7RYR6rDly3N59I4X4x4DWDKLYriAAcIWTGN%2B4MZCYBRHNgOjGnkmgcTrgK6CGx2j%2BhLE31UwqbSWrgY6ngGdEoaBlNF2C%2BS8tuoMV1i8gjLY8swOGyJ3pTPJ1RXkiIh7ltbF33%2F9b4yvqCoUuU7ClpcfQxoClJAeGUBCSg14yYzkBycl%2FgThA15qk%2F32f7a1c3jLFcKwartfHWNC%2FKiGL4kBWATPBHmQu5C74w5QDuk6IHJXfBv33nCBKq%2BXZ7M0z40f4xvxEAaeUo2XzdnawPV7knCx726TkdsprQ%3D%3D&Expires=1707450673
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 52.216.52.169, 52.216.12.124, 52.217.226.177, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|52.216.52.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# mecab-ko-dic-2.1.1-20180720.tar.gz: No such file or directory
#
# Cannot write to ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ (Success).
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# tar (child): mecab-ko-dic-2.1.1-20180720.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# chdir: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# /bin/bash: line 1: cd: mecab-ko-dic-2.1.1-20180720: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# /bin/bash: line 1: ./configure: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# make: getcwd: No such file or directory
# make: *** No targets specified and no makefile found.  Stop.
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# make: getcwd: No such file or directory
# make: *** No rule to make target 'install'.  Stop.

# %%
# !wget https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# !tar xvfz mecab-ko-dic-2.1.1-20180720.tar.gz
# %cd mecab-ko-dic-2.1.1-20180720
# Out:
# --2024-02-09 03:28:17--  https://bitbucket.org/eunjeon/mecab-ko-dic/downloads/mecab-ko-dic-2.1.1-20180720.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::22c0:3470
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNOAB6267T&Signature=OLvxm%2B6kmN0f0ha8jqSr%2F9iC%2FiY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEDQaCXVzLWVhc3QtMSJGMEQCIAIGL19mAeAh%2BY5nkToBdyPTC13TcGH8RFtSu1Qv4AKrAiBVaYnJNTP4q7d5dFb7FgzqxLgNSJHdafMm56FJvIZffyqwAgj8%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDk4NDUyNTEwMTE0NiIMotXIFawQuGYpxN2SKoQCtc4xTz3YEEcdCqyTd8RbpShT8naFdnAahZ8nEhjWkb5SVIEQlPe8D7rg2KJU2TrML3P4TCvEU9IFI3KlF%2Bi3OTIwdI1VNCJ7e0h3HUw8iAIIgWiA1mgfAUtsbk02OuRQsYQRjYAH0JGq16dffoImuI%2BO0OVbKX1rpBeyu%2F0iMCMMybfcvhzXzQH6DZPJgHcviSME9M2T45kc%2BpsVFV2rlD9L3mQpSpZvm%2BXUu5cyBXL%2F8GdT09y%2B4KSASQbDuCgQsvQ0yMxku6Eas%2FbjCud%2B7RYR6rDly3N59I4X4x4DWDKLYriAAcIWTGN%2B4MZCYBRHNgOjGnkmgcTrgK6CGx2j%2BhLE31UwqbSWrgY6ngGdEoaBlNF2C%2BS8tuoMV1i8gjLY8swOGyJ3pTPJ1RXkiIh7ltbF33%2F9b4yvqCoUuU7ClpcfQxoClJAeGUBCSg14yYzkBycl%2FgThA15qk%2F32f7a1c3jLFcKwartfHWNC%2FKiGL4kBWATPBHmQu5C74w5QDuk6IHJXfBv33nCBKq%2BXZ7M0z40f4xvxEAaeUo2XzdnawPV7knCx726TkdsprQ%3D%3D&Expires=1707450673 [following]
# --2024-02-09 03:28:18--  https://bbuseruploads.s3.amazonaws.com/a4fcd83e-34f1-454e-a6ac-c242c7d434d3/downloads/b5a0c703-7b64-45ed-a2d7-180e962710b6/mecab-ko-dic-2.1.1-20180720.tar.gz?response-content-disposition=attachment%3B%20filename%3D%22mecab-ko-dic-2.1.1-20180720.tar.gz%22&response-content-encoding=None&AWSAccessKeyId=ASIA6KOSE3BNOAB6267T&Signature=OLvxm%2B6kmN0f0ha8jqSr%2F9iC%2FiY%3D&x-amz-security-token=IQoJb3JpZ2luX2VjEDQaCXVzLWVhc3QtMSJGMEQCIAIGL19mAeAh%2BY5nkToBdyPTC13TcGH8RFtSu1Qv4AKrAiBVaYnJNTP4q7d5dFb7FgzqxLgNSJHdafMm56FJvIZffyqwAgj8%2F%2F%2F%2F%2F%2F%2F%2F%2F%2F8BEAAaDDk4NDUyNTEwMTE0NiIMotXIFawQuGYpxN2SKoQCtc4xTz3YEEcdCqyTd8RbpShT8naFdnAahZ8nEhjWkb5SVIEQlPe8D7rg2KJU2TrML3P4TCvEU9IFI3KlF%2Bi3OTIwdI1VNCJ7e0h3HUw8iAIIgWiA1mgfAUtsbk02OuRQsYQRjYAH0JGq16dffoImuI%2BO0OVbKX1rpBeyu%2F0iMCMMybfcvhzXzQH6DZPJgHcviSME9M2T45kc%2BpsVFV2rlD9L3mQpSpZvm%2BXUu5cyBXL%2F8GdT09y%2B4KSASQbDuCgQsvQ0yMxku6Eas%2FbjCud%2B7RYR6rDly3N59I4X4x4DWDKLYriAAcIWTGN%2B4MZCYBRHNgOjGnkmgcTrgK6CGx2j%2BhLE31UwqbSWrgY6ngGdEoaBlNF2C%2BS8tuoMV1i8gjLY8swOGyJ3pTPJ1RXkiIh7ltbF33%2F9b4yvqCoUuU7ClpcfQxoClJAeGUBCSg14yYzkBycl%2FgThA15qk%2F32f7a1c3jLFcKwartfHWNC%2FKiGL4kBWATPBHmQu5C74w5QDuk6IHJXfBv33nCBKq%2BXZ7M0z40f4xvxEAaeUo2XzdnawPV7knCx726TkdsprQ%3D%3D&Expires=1707450673
# Resolving bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)... 54.231.197.73, 54.231.227.1, 52.216.61.249, ...
# Connecting to bbuseruploads.s3.amazonaws.com (bbuseruploads.s3.amazonaws.com)|54.231.197.73|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49775061 (47M) [application/x-tar]
# Saving to: ‘mecab-ko-dic-2.1.1-20180720.tar.gz’
#
# mecab-ko-dic-2.1.1- 100%[===================>]  47.47M  23.1MB/s    in 2.1s
#
# 2024-02-09 03:28:20 (23.1 MB/s) - ‘mecab-ko-dic-2.1.1-20180720.tar.gz’ saved [49775061/49775061]
#
# mecab-ko-dic-2.1.1-20180720/
# mecab-ko-dic-2.1.1-20180720/configure
# mecab-ko-dic-2.1.1-20180720/COPYING
# mecab-ko-dic-2.1.1-20180720/autogen.sh
# mecab-ko-dic-2.1.1-20180720/Place-station.csv
# mecab-ko-dic-2.1.1-20180720/NNG.csv
# mecab-ko-dic-2.1.1-20180720/README
# mecab-ko-dic-2.1.1-20180720/EF.csv
# mecab-ko-dic-2.1.1-20180720/MAG.csv
# mecab-ko-dic-2.1.1-20180720/Preanalysis.csv
# mecab-ko-dic-2.1.1-20180720/NNB.csv
# mecab-ko-dic-2.1.1-20180720/Person-actor.csv
# mecab-ko-dic-2.1.1-20180720/VV.csv
# mecab-ko-dic-2.1.1-20180720/Makefile.in
# mecab-ko-dic-2.1.1-20180720/matrix.def
# mecab-ko-dic-2.1.1-20180720/EC.csv
# mecab-ko-dic-2.1.1-20180720/NNBC.csv
# mecab-ko-dic-2.1.1-20180720/clean
# mecab-ko-dic-2.1.1-20180720/ChangeLog
# mecab-ko-dic-2.1.1-20180720/J.csv
# mecab-ko-dic-2.1.1-20180720/.keep
# mecab-ko-dic-2.1.1-20180720/feature.def
# mecab-ko-dic-2.1.1-20180720/Foreign.csv
# mecab-ko-dic-2.1.1-20180720/XPN.csv
# mecab-ko-dic-2.1.1-20180720/EP.csv
# mecab-ko-dic-2.1.1-20180720/NR.csv
# mecab-ko-dic-2.1.1-20180720/left-id.def
# mecab-ko-dic-2.1.1-20180720/Place.csv
# mecab-ko-dic-2.1.1-20180720/Symbol.csv
# mecab-ko-dic-2.1.1-20180720/dicrc
# mecab-ko-dic-2.1.1-20180720/NP.csv
# mecab-ko-dic-2.1.1-20180720/ETM.csv
# mecab-ko-dic-2.1.1-20180720/IC.csv
# mecab-ko-dic-2.1.1-20180720/Place-address.csv
# mecab-ko-dic-2.1.1-20180720/Group.csv
# mecab-ko-dic-2.1.1-20180720/model.def
# mecab-ko-dic-2.1.1-20180720/XSN.csv
# mecab-ko-dic-2.1.1-20180720/INSTALL
# mecab-ko-dic-2.1.1-20180720/rewrite.def
# mecab-ko-dic-2.1.1-20180720/Inflect.csv
# mecab-ko-dic-2.1.1-20180720/configure.ac
# mecab-ko-dic-2.1.1-20180720/NNP.csv
# mecab-ko-dic-2.1.1-20180720/CoinedWord.csv
# mecab-ko-dic-2.1.1-20180720/XSV.csv
# mecab-ko-dic-2.1.1-20180720/pos-id.def
# mecab-ko-dic-2.1.1-20180720/Makefile.am
# mecab-ko-dic-2.1.1-20180720/unk.def
# mecab-ko-dic-2.1.1-20180720/missing
# mecab-ko-dic-2.1.1-20180720/VCP.csv
# mecab-ko-dic-2.1.1-20180720/install-sh
# mecab-ko-dic-2.1.1-20180720/Hanja.csv
# mecab-ko-dic-2.1.1-20180720/MAJ.csv
# mecab-ko-dic-2.1.1-20180720/XSA.csv
# mecab-ko-dic-2.1.1-20180720/Wikipedia.csv
# mecab-ko-dic-2.1.1-20180720/tools/
# mecab-ko-dic-2.1.1-20180720/tools/add-userdic.sh
# mecab-ko-dic-2.1.1-20180720/tools/mecab-bestn.sh
# mecab-ko-dic-2.1.1-20180720/tools/convert_for_using_store.sh
# mecab-ko-dic-2.1.1-20180720/user-dic/
# mecab-ko-dic-2.1.1-20180720/user-dic/nnp.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/place.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/person.csv
# mecab-ko-dic-2.1.1-20180720/user-dic/README.md
# mecab-ko-dic-2.1.1-20180720/NorthKorea.csv
# mecab-ko-dic-2.1.1-20180720/VX.csv
# mecab-ko-dic-2.1.1-20180720/right-id.def
# mecab-ko-dic-2.1.1-20180720/VA.csv
# mecab-ko-dic-2.1.1-20180720/char.def
# mecab-ko-dic-2.1.1-20180720/NEWS
# mecab-ko-dic-2.1.1-20180720/MM.csv
# mecab-ko-dic-2.1.1-20180720/ETN.csv
# mecab-ko-dic-2.1.1-20180720/AUTHORS
# mecab-ko-dic-2.1.1-20180720/Person.csv
# mecab-ko-dic-2.1.1-20180720/XR.csv
# mecab-ko-dic-2.1.1-20180720/VCN.csv
# /content/mecab-0.996-ko-0.9.2/mecab-ko-dic-2.1.1-20180720

# %%
# !./autogen.sh
# !./configure
# !make
# !make install
# Out:
# Looking in current directory for macros.
# configure.ac:2: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.
# ./lib/autoconf/general.m4:2434: AC_DIAGNOSE is expanded from...
# aclocal.m4:139: AM_INIT_AUTOMAKE is expanded from...
# configure.ac:2: the top level
# configure.ac:56: warning: AC_OUTPUT should be used without arguments.
# configure.ac:56: You should run autoupdate.
# configure.ac:2: warning: AM_INIT_AUTOMAKE: two- and three-arguments forms are deprecated.  For more info, see:
# configure.ac:2: https://www.gnu.org/software/automake/manual/automake.html#Modernize-AM_005fINIT_005fAUTOMAKE-invocation
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# /content/mecab-0.996-ko-0.9.2/mecab-ko-dic-2.1.1-20180720/missing: Unknown `--is-lightweight' option
# Try `/content/mecab-0.996-ko-0.9.2/mecab-ko-dic-2.1.1-20180720/missing --help' for more information
# configure: WARNING: 'missing' script is too old or missing
# checking for a race-free mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking whether make supports nested variables... yes
# checking for mecab-config... /usr/local/bin/mecab-config
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating Makefile
# /usr/local/libexec/mecab/mecab-dict-index -d . -o . -f UTF-8 -t UTF-8
# reading ./unk.def ... 13
# emitting double-array: 100% |###########################################|
# reading ./XSN.csv ... 124
# reading ./Wikipedia.csv ... 36762
# reading ./Inflect.csv ... 44820
# reading ./MAJ.csv ... 240
# reading ./NNBC.csv ... 677
# reading ./VX.csv ... 125
# reading ./NNG.csv ... 208524
# reading ./CoinedWord.csv ... 148
# reading ./NNB.csv ... 140
# reading ./Hanja.csv ... 125750
# reading ./XSV.csv ... 23
# reading ./ETN.csv ... 14
# reading ./Place-address.csv ... 19301
# reading ./Place.csv ... 30303
# reading ./EC.csv ... 2547
# reading ./XR.csv ... 3637
# reading ./ETM.csv ... 133
# reading ./NorthKorea.csv ... 3
# reading ./NNP.csv ... 2371
# reading ./J.csv ... 416
# reading ./EP.csv ... 51
# reading ./Symbol.csv ... 16
# reading ./NP.csv ... 342
# reading ./Preanalysis.csv ... 5
# reading ./Foreign.csv ... 11690
# reading ./VA.csv ... 2360
# reading ./VV.csv ... 7331
# reading ./NR.csv ... 482
# reading ./Person.csv ... 196459
# reading ./Group.csv ... 3176
# reading ./MM.csv ... 453
# reading ./VCN.csv ... 7
# reading ./XPN.csv ... 83
# reading ./EF.csv ... 1820
# reading ./Person-actor.csv ... 99230
# reading ./IC.csv ... 1305
# reading ./MAG.csv ... 14242
# reading ./XSA.csv ... 19
# reading ./VCP.csv ... 9
# reading ./Place-station.csv ... 1145
# emitting double-array: 100% |###########################################|
# reading ./matrix.def ... 3822x2693
# emitting matrix      : 100% |###########################################|
#
# done!
# echo To enable dictionary, rewrite /usr/local/etc/mecabrc as \"dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic\"
# To enable dictionary, rewrite /usr/local/etc/mecabrc as "dicdir = /usr/local/lib/mecab/dic/mecab-ko-dic"
# make[1]: Entering directory '/content/mecab-0.996-ko-0.9.2/mecab-ko-dic-2.1.1-20180720'
# make[1]: Nothing to be done for 'install-exec-am'.
#  /usr/bin/mkdir -p '/usr/local/lib/mecab/dic/mecab-ko-dic'
#  /usr/bin/install -c -m 644 model.bin matrix.bin char.bin sys.dic unk.dic left-id.def right-id.def rewrite.def pos-id.def dicrc '/usr/local/lib/mecab/dic/mecab-ko-dic'
# make[1]: Leaving directory '/content/mecab-0.996-ko-0.9.2/mecab-ko-dic-2.1.1-20180720'

# %%
## 3. mecab-python 설치

# !git clone https://bitbucket.org/eunjeon/mecab-python-0.996.git
#!cd mecab-python-0.996
# %cd /content/mecab-0.996-ko-0.9.2/mecab-python-0.996/
# !python setup.py build
# !python setup.py install
#출처: https://jongsky.tistory.com/30 [시간의 농도:티스토리]
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: could not create work tree dir 'mecab-python-0.996': No such file or directory
# [Errno 2] No such file or directory: '/content/mecab-0.996-ko-0.9.2/mecab-python-0.996/'
# /content/mecab-0.996-ko-0.9.2/mecab-python-0.996
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# python3: can't open file 'setup.py': [Errno 2] No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# python3: can't open file 'setup.py': [Errno 2] No such file or directory

# %%
# !git clone https://bitbucket.org/eunjeon/mecab-python-0.996.git
# %cd mecab-python-0.996
# Out:
# Cloning into 'mecab-python-0.996'...
# Unpacking objects: 100% (17/17), 59.65 KiB | 2.84 MiB/s, done.
# /content/mecab-0.996-ko-0.9.2/mecab-ko-dic-2.1.1-20180720/mecab-python-0.996

# %%
# setup.py 파일 경로
setup_py_path = '/content/mecab-0.996-ko-0.9.2/mecab-ko-dic-2.1.1-20180720/mecab-python-0.996/setup.py'

# 파일 읽기
with open(setup_py_path, 'r') as file:
    lines = file.readlines()

# 버전 정보 수정
new_lines = []
for line in lines:
    if 'version =' in line:
        # 버전 번호를 PEP 440 형식으로 수정
        new_line = '    version = "0.996+ko0.9.2",  # PEP 440 형식으로 수정\n'
        new_lines.append(new_line)
    else:
        new_lines.append(line)

# 수정된 내용으로 파일 다시 쓰기
with open(setup_py_path, 'w') as file:
    file.writelines(new_lines)

# 수정된 파일 확인 (선택적)
# !cat /content/mecab-0.996-ko-0.9.2/mecab-ko-dic-2.1.1-20180720/mecab-python-0.996/setup.py
# Out:
# #!/usr/bin/env python
#
# from distutils.core import setup,Extension,os
# import string
#
# def cmd1(str):
#     return os.popen(str).readlines()[0][:-1]
#
# def cmd2(str):
#     return cmd1(str).split()
#
# setup(name = "mecab-python",
#     version = "0.996+ko0.9.2",  # PEP 440 형식으로 수정
# 	py_modules=["MeCab"],
# 	ext_modules = [
# 		Extension("_MeCab",
# 			["MeCab_wrap.cxx",],
# 			include_dirs=cmd2("mecab-config --inc-dir"),
# 			library_dirs=cmd2("mecab-config --libs-only-L"),
# 			libraries=cmd2("mecab-config --libs-only-l"))
# 			])

# %%
# !python setup.py build
# !python setup.py install
# Out:
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# zip_safe flag not set; analyzing archive contents...
# __pycache__.MeCab.cpython-310: module references __file__
# __pycache__._MeCab.cpython-310: module references __file__

# %%
# !pip3 install mecab-python3
# Out:
# Requirement already satisfied: mecab-python3 in /usr/local/lib/python3.10/dist-packages (1.0.8)

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.4/19.4 MB 44.4 MB/s eta 0:00:00
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading JPype1-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (488 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 39.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from konlpy) (4.9.4)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.10/dist-packages (from konlpy) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from JPype1>=0.7.0->konlpy) (23.2)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.5.0 konlpy-0.6.0

# %%
from konlpy.tag import Mecab

mecab = Mecab()
mecab.morphs('흔히 나이가 그 기준이 되지만, 우리 삶의 어떤 부분을 가리켜 특히 그걸 꽃다운 시절이라든가 하는 식으로 표현하는 수가 있다. 그러나 세상 일이 항상 그러하듯, 꽃답다는 것은 한번 그늘지고 시들기 시작하면 그만큼 더 처참하고 황폐하기 마련이다.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/konlpy/tag/_mecab.py in __init__(self, dicpath)
#      76         try:
# ---> 77             self.tagger = Tagger('-d %s' % dicpath)
#      78             self.tagset = utils.read_json('%s/data/tagset/mecab.json' % utils.installpath)
#
# NameError: name 'Tagger' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-24-25f8cc59654b> in <cell line: 3>()
#       1 from konlpy.tag import Mecab
#       2
# ----> 3 mecab = Mecab()
#       4 mecab.morphs('흔히 나이가 그 기준이 되지만, 우리 삶의 어떤 부분을 가리켜 특히 그걸 꽃다운 시절이라든가 하는 식으로 표현하는 수가 있다. 그러나 세상 일이 항상 그러하듯, 꽃답다는 것은 한번 그늘지고 시들기 시작하면 그만큼 더 처참하고 황폐하기 마련이다.')
#
# /usr/local/lib/python3.10/dist-packages/konlpy/tag/_mecab.py in __init__(self, dicpath)
#      80             raise Exception('The MeCab dictionary does not exist at "%s". Is the dictionary correctly installed?\nYou can also try entering the dictionary path when initializing the Mecab class: "Mecab(\'/some/dic/path\')"' % dicpath)
#      81         except NameError:
# ---> 82             raise Exception('Install MeCab in order to use it: http://konlpy.org/en/latest/install/')
#      83
#      84     def __setstate__(self, state):
#
# Exception: Install MeCab in order to use it: http://konlpy.org/en/latest/install/

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools

# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null

# !apt-get update -qq 2>&1 > /dev/null

# !apt-get -y install -qq google-drive-ocamlfuse fuse

from google.colab import auth
auth.authenticate_user()

from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()

import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL

vcode = getpass.getpass()

# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# !mkdir -p Gdrive
# !google-drive-ocamlfuse Gdrive
# !ls Gdrive
# Out:
# E: Package 'python-software-properties' has no installation candidate
# E: Package 'module-init-tools' has no installation candidate
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=None&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ee8d5432d20b> in <cell line: 18>()
#      16 get_ipython().system('google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL')
#      17
# ---> 18 vcode = getpass.getpass()
#      19
#      20 get_ipython().system('echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}')
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in getpass(self, prompt, stream)
#     832             warnings.warn("The `stream` parameter of `getpass.getpass` will have no effect when using ipykernel",
#     833                     UserWarning, stacklevel=2)
# --> 834         return self._input_request(prompt,
#     835             self._parent_ident,
#     836             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %% [markdown]
# # Mecab 설치

# %%
# Out:
# Mounted at /content/drive

# %%
# !pip install mecab-python3
# Out:
# Collecting mecab-python3
#   Downloading mecab_python3-1.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (581 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 581.7/581.7 kB 4.1 MB/s eta 0:00:00
# Installing collected packages: mecab-python3
# Successfully installed mecab-python3-1.0.8

# %%
import MeCab

# MeCab 객체 생성
mecab = MeCab.Tagger()
text = '흔히 나이가 그 기준이 되지만, 우리 삶의 어떤 부분을 가리켜 특히 그걸 꽃다운 시절이라든가 하는 식으로 표현하는 수가 있다. 그러나 세상 일이 항상 그러하듯, 꽃답다는 것은 한번 그늘지고 시들기 시작하면 그만큼 더 처참하고 황폐하기 마련이다.'

def get_morphs(text):
    mecab = MeCab.Tagger()
    parsed = mecab.parse(text)
    morphs = []
    for line in parsed.split('\n'):
        if line == 'EOS' or line == '':
            continue
        morphs.append(line.split('\t')[0])
    return morphs

# 형태소만 추출
morphs = get_morphs(text)
print(morphs)
# Out:
# ['흔히', '나이', '가', '그', '기준', '이', '되', '지만', ',', '우리', '삶', '의', '어떤', '부분', '을', '가리켜', '특히', '그걸', '꽃', '다운', '시절', '이', '라든가', '하', '는', '식', '으로', '표현', '하', '는', '수', '가', '있', '다', '.', '그러나', '세상', '일', '이', '항상', '그러', '하', '듯', ',', '꽃', '답', '다는', '것', '은', '한', '번', '그늘지', '고', '시들', '기', '시작', '하', '면', '그만큼', '더', '처참', '하', '고', '황폐', '하', '기', '마련', '이', '다', '.']

# %% [markdown]
# # 패키지로드

# %%
# !pip install transformers
# !pip install tensorboardx
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Collecting tensorboardx
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from tensorboardx) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorboardx) (23.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardx) (3.20.3)
# Installing collected packages: tensorboardx
# Successfully installed tensorboardx-2.6.2.2

# %% [markdown]
# # pyrouge

# %%
# !pip install pyrouge --upgrade
# !pip install https://github.com/bheinzerling/pyrouge/archive/master.zip
# !pip install pyrouge
# !pip show pyrouge
# !git clone https://github.com/andersjo/pyrouge.git
from pyrouge import Rouge155
# !pyrouge_set_rouge_path 'pyrouge/tools/ROUGE-1.5.5'
# Out:
# Collecting pyrouge
#   Downloading pyrouge-0.1.3.tar.gz (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pyrouge
#   Building wheel for pyrouge (setup.py) ... done
#   Created wheel for pyrouge: filename=pyrouge-0.1.3-py3-none-any.whl size=191605 sha256=2c7f495db9505bbf7410350663a505e155b7b571f3e2e8042d812d36fc0cfbda
#   Stored in directory: /root/.cache/pip/wheels/9a/67/12/c5dd8ef8b4152bb8789eafd2a74a734e2dc7bb9eae02b768e7
# Successfully built pyrouge
# Installing collected packages: pyrouge
# Successfully installed pyrouge-0.1.3
# Collecting https://github.com/bheinzerling/pyrouge/archive/master.zip
#   Downloading https://github.com/bheinzerling/pyrouge/archive/master.zip
#      \ 202.3 kB 2.6 MB/s 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyrouge in /usr/local/lib/python3.10/dist-packages (0.1.3)
# Name: pyrouge
# Version: 0.1.3
# Summary: A Python wrapper for the ROUGE summarization evaluation package.
# Home-page: https://github.com/noutenki/pyrouge
# Author: Benjamin Heinzerling, Anders Johannsen
# Author-email: benjamin.heinzerling@h-its.org
# License: LICENSE.txt
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by:
# Cloning into 'pyrouge'...
# remote: Enumerating objects: 393, done.
# remote: Total 393 (delta 0), reused 0 (delta 0), pack-reused 393
# Receiving objects: 100% (393/393), 298.74 KiB | 3.51 MiB/s, done.
# Resolving deltas: 100% (109/109), done.
# 2024-02-09 04:01:40,019 [MainThread  ] [INFO ]  Set ROUGE home directory to pyrouge/tools/ROUGE-1.5.5.

# %%
# !sudo apt-get install libxml-parser-perl
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libauthen-sasl-perl libclone-perl libdata-dump-perl libencode-locale-perl
#   libfile-listing-perl libfont-afm-perl libhtml-form-perl libhtml-format-perl
#   libhtml-parser-perl libhtml-tagset-perl libhtml-tree-perl
#   libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libio-html-perl
#   libio-socket-ssl-perl liblwp-mediatypes-perl liblwp-protocol-https-perl
#   libmailtools-perl libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl
#   libtry-tiny-perl liburi-perl libwww-perl libwww-robotrules-perl netbase
#   perl-openssl-defaults
# Suggested packages:
#   libdigest-hmac-perl libgssapi-perl libcrypt-ssleay-perl libsub-name-perl
#   libbusiness-isbn-perl libauthen-ntlm-perl
# The following NEW packages will be installed:
#   libauthen-sasl-perl libclone-perl libdata-dump-perl libencode-locale-perl
#   libfile-listing-perl libfont-afm-perl libhtml-form-perl libhtml-format-perl
#   libhtml-parser-perl libhtml-tagset-perl libhtml-tree-perl
#   libhttp-cookies-perl libhttp-daemon-perl libhttp-date-perl
#   libhttp-message-perl libhttp-negotiate-perl libio-html-perl
#   libio-socket-ssl-perl liblwp-mediatypes-perl liblwp-protocol-https-perl
#   libmailtools-perl libnet-http-perl libnet-smtp-ssl-perl libnet-ssleay-perl
#   libtry-tiny-perl liburi-perl libwww-perl libwww-robotrules-perl
#   libxml-parser-perl netbase perl-openssl-defaults
# 0 upgraded, 31 newly installed, 0 to remove and 35 not upgraded.
# Need to get 1,783 kB of archives.
# After this operation, 5,562 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 netbase all 6.3 [12.9 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclone-perl amd64 0.45-1build3 [11.0 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdata-dump-perl all 1.25-1 [25.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libencode-locale-perl all 1.05-1.1 [11.8 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-date-perl all 6.05-1 [9,920 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfile-listing-perl all 6.14-1 [11.2 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfont-afm-perl all 1.20-3 [13.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-tagset-perl all 3.20-4 [12.5 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 liburi-perl all 5.10-1 [78.8 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-parser-perl amd64 3.76-1build2 [88.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libio-html-perl all 1.004-2 [15.4 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblwp-mediatypes-perl all 6.04-1 [19.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-message-perl all 6.36-1 [76.8 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-form-perl all 6.07-1 [22.2 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-tree-perl all 5.07-2 [200 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-format-perl all 2.12-1.1 [41.3 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-cookies-perl all 6.10-1 [18.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libhttp-daemon-perl all 6.13-1ubuntu0.1 [22.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-negotiate-perl all 6.01-1 [12.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 perl-openssl-defaults amd64 5build2 [7,542 B]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnet-ssleay-perl amd64 1.92-1build2 [327 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 libio-socket-ssl-perl all 2.074-2 [192 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnet-http-perl all 6.22-1 [23.2 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtry-tiny-perl all 0.31-1 [21.8 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwww-robotrules-perl all 6.02-1 [12.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwww-perl all 6.61-1 [141 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblwp-protocol-https-perl all 6.10-1 [10.9 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnet-smtp-ssl-perl all 1.04-1 [5,948 B]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmailtools-perl all 2.21-1 [80.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxml-parser-perl amd64 2.46-3build1 [212 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libauthen-sasl-perl all 2.1600-1.1 [43.1 kB]
# Fetched 1,783 kB in 3s (618 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 31.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package netbase.
# (Reading database ... 122681 files and directories currently installed.)
# Preparing to unpack .../00-netbase_6.3_all.deb ...
# Unpacking netbase (6.3) ...
# Selecting previously unselected package libclone-perl.
# Preparing to unpack .../01-libclone-perl_0.45-1build3_amd64.deb ...
# Unpacking libclone-perl (0.45-1build3) ...
# Selecting previously unselected package libdata-dump-perl.
# Preparing to unpack .../02-libdata-dump-perl_1.25-1_all.deb ...
# Unpacking libdata-dump-perl (1.25-1) ...
# Selecting previously unselected package libencode-locale-perl.
# Preparing to unpack .../03-libencode-locale-perl_1.05-1.1_all.deb ...
# Unpacking libencode-locale-perl (1.05-1.1) ...
# Selecting previously unselected package libhttp-date-perl.
# Preparing to unpack .../04-libhttp-date-perl_6.05-1_all.deb ...
# Unpacking libhttp-date-perl (6.05-1) ...
# Selecting previously unselected package libfile-listing-perl.
# Preparing to unpack .../05-libfile-listing-perl_6.14-1_all.deb ...
# Unpacking libfile-listing-perl (6.14-1) ...
# Selecting previously unselected package libfont-afm-perl.
# Preparing to unpack .../06-libfont-afm-perl_1.20-3_all.deb ...
# Unpacking libfont-afm-perl (1.20-3) ...
# Selecting previously unselected package libhtml-tagset-perl.
# Preparing to unpack .../07-libhtml-tagset-perl_3.20-4_all.deb ...
# Unpacking libhtml-tagset-perl (3.20-4) ...
# Selecting previously unselected package liburi-perl.
# Preparing to unpack .../08-liburi-perl_5.10-1_all.deb ...
# Unpacking liburi-perl (5.10-1) ...
# Selecting previously unselected package libhtml-parser-perl:amd64.
# Preparing to unpack .../09-libhtml-parser-perl_3.76-1build2_amd64.deb ...
# Unpacking libhtml-parser-perl:amd64 (3.76-1build2) ...
# Selecting previously unselected package libio-html-perl.
# Preparing to unpack .../10-libio-html-perl_1.004-2_all.deb ...
# Unpacking libio-html-perl (1.004-2) ...
# Selecting previously unselected package liblwp-mediatypes-perl.
# Preparing to unpack .../11-liblwp-mediatypes-perl_6.04-1_all.deb ...
# Unpacking liblwp-mediatypes-perl (6.04-1) ...
# Selecting previously unselected package libhttp-message-perl.
# Preparing to unpack .../12-libhttp-message-perl_6.36-1_all.deb ...
# Unpacking libhttp-message-perl (6.36-1) ...
# Selecting previously unselected package libhtml-form-perl.
# Preparing to unpack .../13-libhtml-form-perl_6.07-1_all.deb ...
# Unpacking libhtml-form-perl (6.07-1) ...
# Selecting previously unselected package libhtml-tree-perl.
# Preparing to unpack .../14-libhtml-tree-perl_5.07-2_all.deb ...
# Unpacking libhtml-tree-perl (5.07-2) ...
# Selecting previously unselected package libhtml-format-perl.
# Preparing to unpack .../15-libhtml-format-perl_2.12-1.1_all.deb ...
# Unpacking libhtml-format-perl (2.12-1.1) ...
# Selecting previously unselected package libhttp-cookies-perl.
# Preparing to unpack .../16-libhttp-cookies-perl_6.10-1_all.deb ...
# Unpacking libhttp-cookies-perl (6.10-1) ...
# Selecting previously unselected package libhttp-daemon-perl.
# Preparing to unpack .../17-libhttp-daemon-perl_6.13-1ubuntu0.1_all.deb ...
# Unpacking libhttp-daemon-perl (6.13-1ubuntu0.1) ...
# Selecting previously unselected package libhttp-negotiate-perl.
# Preparing to unpack .../18-libhttp-negotiate-perl_6.01-1_all.deb ...
# Unpacking libhttp-negotiate-perl (6.01-1) ...
# Selecting previously unselected package perl-openssl-defaults:amd64.
# Preparing to unpack .../19-perl-openssl-defaults_5build2_amd64.deb ...
# Unpacking perl-openssl-defaults:amd64 (5build2) ...
# Selecting previously unselected package libnet-ssleay-perl:amd64.
# Preparing to unpack .../20-libnet-ssleay-perl_1.92-1build2_amd64.deb ...
# Unpacking libnet-ssleay-perl:amd64 (1.92-1build2) ...
# Selecting previously unselected package libio-socket-ssl-perl.
# Preparing to unpack .../21-libio-socket-ssl-perl_2.074-2_all.deb ...
# Unpacking libio-socket-ssl-perl (2.074-2) ...
# Selecting previously unselected package libnet-http-perl.
# Preparing to unpack .../22-libnet-http-perl_6.22-1_all.deb ...
# Unpacking libnet-http-perl (6.22-1) ...
# Selecting previously unselected package libtry-tiny-perl.
# Preparing to unpack .../23-libtry-tiny-perl_0.31-1_all.deb ...
# Unpacking libtry-tiny-perl (0.31-1) ...
# Selecting previously unselected package libwww-robotrules-perl.
# Preparing to unpack .../24-libwww-robotrules-perl_6.02-1_all.deb ...
# Unpacking libwww-robotrules-perl (6.02-1) ...
# Selecting previously unselected package libwww-perl.
# Preparing to unpack .../25-libwww-perl_6.61-1_all.deb ...
# Unpacking libwww-perl (6.61-1) ...
# Selecting previously unselected package liblwp-protocol-https-perl.
# Preparing to unpack .../26-liblwp-protocol-https-perl_6.10-1_all.deb ...
# Unpacking liblwp-protocol-https-perl (6.10-1) ...
# Selecting previously unselected package libnet-smtp-ssl-perl.
# Preparing to unpack .../27-libnet-smtp-ssl-perl_1.04-1_all.deb ...
# Unpacking libnet-smtp-ssl-perl (1.04-1) ...
# Selecting previously unselected package libmailtools-perl.
# Preparing to unpack .../28-libmailtools-perl_2.21-1_all.deb ...
# Unpacking libmailtools-perl (2.21-1) ...
# Selecting previously unselected package libxml-parser-perl:amd64.
# Preparing to unpack .../29-libxml-parser-perl_2.46-3build1_amd64.deb ...
# Unpacking libxml-parser-perl:amd64 (2.46-3build1) ...
# Selecting previously unselected package libauthen-sasl-perl.
# Preparing to unpack .../30-libauthen-sasl-perl_2.1600-1.1_all.deb ...
# Unpacking libauthen-sasl-perl (2.1600-1.1) ...
# Setting up libhttp-date-perl (6.05-1) ...
# Setting up libfile-listing-perl (6.14-1) ...
# Setting up libfont-afm-perl (1.20-3) ...
# Setting up libclone-perl (0.45-1build3) ...
# Setting up libhtml-tagset-perl (3.20-4) ...
# Setting up libauthen-sasl-perl (2.1600-1.1) ...
# Setting up liblwp-mediatypes-perl (6.04-1) ...
# Setting up libtry-tiny-perl (0.31-1) ...
# Setting up perl-openssl-defaults:amd64 (5build2) ...
# Setting up libencode-locale-perl (1.05-1.1) ...
# Setting up libdata-dump-perl (1.25-1) ...
# Setting up libio-html-perl (1.004-2) ...
# Setting up netbase (6.3) ...
# Setting up liburi-perl (5.10-1) ...
# Setting up libhttp-message-perl (6.36-1) ...
# Setting up libnet-ssleay-perl:amd64 (1.92-1build2) ...
# Setting up libhttp-negotiate-perl (6.01-1) ...
# Setting up libhttp-cookies-perl (6.10-1) ...
# Setting up libnet-http-perl (6.22-1) ...
# Setting up libwww-robotrules-perl (6.02-1) ...
# Setting up libhttp-daemon-perl (6.13-1ubuntu0.1) ...
# Setting up libhtml-parser-perl:amd64 (3.76-1build2) ...
# Setting up libio-socket-ssl-perl (2.074-2) ...
# Setting up libhtml-form-perl (6.07-1) ...
# Setting up libhtml-tree-perl (5.07-2) ...
# Setting up libhtml-format-perl (2.12-1.1) ...
# Setting up libnet-smtp-ssl-perl (1.04-1) ...
# Setting up libmailtools-perl (2.21-1) ...
# Setting up liblwp-protocol-https-perl (6.10-1) ...
# Setting up libwww-perl (6.61-1) ...
# Setting up libxml-parser-perl:amd64 (2.46-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
# %%shell
# cd pyrouge/tools/ROUGE-1.5.5/data
# rm WordNet-2.0.exc.db # only if exist
# cd WordNet-2.0-Exceptions
# rm WordNet-2.0.exc.db # only if exist
#
# ./buildExeptionDB.pl . exc WordNet-2.0.exc.db
# cd ../
# ln -s WordNet-2.0-Exceptions/WordNet-2.0.exc.db WordNet-2.0.exc.db
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# indwelt
# inferred
# inferring
# initialled
# initialling
# inlaid
# insetting
# inspanned
# inspanning
# installed
# installing
# intensified
# interbred
# intercropped
# intercropping
# intercutting
# interlaid
# interlapped
# interlapping
# intermarried
# intermitted
# intermitting
# interpled
# interred
# interring
# interstratified
# interwove
# interwoven
# intromitted
# intromitting
# inwove
# inwoven
# inwrapped
# inwrapping
# is
# jabbed
# jabbing
# jagged
# jagging
# jammed
# jamming
# japanned
# japanning
# jarred
# jarring
# jellied
# jellified
# jemmied
# jerry-built
# jetted
# jetting
# jewelled
# jewelling
# jibbed
# jibbing
# jigged
# jigging
# jimmied
# jitterbugged
# jitterbugging
# jobbed
# jobbing
# jog-trotted
# jog-trotting
# jogged
# jogging
# joined_battle
# joined_forces
# joining_battle
# joining_forces
# joins_battle
# joins_forces
# jollied
# jollified
# jotted
# jotting
# joy-ridden
# joy-rode
# joypopped
# joypopping
# jugged
# jugging
# jumped_off
# jumping_off
# jumps_off
# justified
# jutted
# jutting
# kenned
# kennelled
# kennelling
# kenning
# kent
# kept
# kernelled
# kernelling
# kidded
# kidding
# kidnapped
# kidnapping
# kipped
# kipping
# knapped
# knapping
# kneecapped
# kneecapping
# knelt
# knew
# knitted
# knitting
# knobbed
# knobbing
# knotted
# knotting
# known
# ko'd
# ko'ing
# ko's
# labelled
# labelling
# laden
# ladyfied
# ladyfies
# ladyfying
# lagged
# lagging
# laid
# lain
# lallygagged
# lallygagging
# lammed
# lamming
# lapidified
# lapped
# lapping
# laurelled
# laurelling
# lay
# layed_for
# laying_for
# lays_for
# leant
# leapfrogged
# leapfrogging
# leapt
# learnt
# leaves_undone
# leaving_undone
# led
# left
# left_undone
# lent
# letting
# levelled
# levelling
# levied
# libelled
# libelling
# lignified
# lipped
# lipping
# liquefied
# liquified
# lit
# lobbed
# lobbied
# lobbing
# logged
# logging
# looked_towards
# looking_towards
# looks_towards
# lopped
# lopping
# lost
# lotted
# lotting
# lugged
# lugging
# lullabied
# lying
# machine-gunned
# machine-gunning
# madded
# madding
# made
# magnified
# manned
# manning
# manumitted
# manumitting
# mapped
# mapping
# marcelled
# marcelling
# marred
# married
# marring
# marshalled
# marshalling
# marvelled
# marvelling
# matted
# matting
# meant
# medalled
# medalling
# met
# metalled
# metalling
# metrified
# might
# militated_against
# militates_against
# militating_against
# mimicked
# mimicking
# minified
# misapplied
# misbecame
# miscarried
# misdealt
# misfitted
# misfitting
# misgave
# misgiven
# mishitting
# mislaid
# misled
# mispled
# misspelt
# misspent
# mistaken
# mistook
# misunderstood
# mobbed
# mobbing
# modelled
# modelling
# modified
# mollified
# molten
# mopped
# mopping
# mortified
# mown
# mudded
# muddied
# mudding
# mugged
# mugging
# multiplied
# mummed
# mummified
# mumming
# mutinied
# mystified
# nabbed
# nabbing
# nagged
# nagging
# napped
# napping
# netted
# netting
# nibbed
# nibbing
# nickelled
# nickelling
# nid-nodded
# nid-nodding
# nidified
# nigrified
# nipped
# nipping
# nitrified
# nodded
# nodding
# non-prossed
# non-prosses
# non-prossing
# nonplussed
# nonplusses
# nonplussing
# notified
# nullified
# nutted
# nutting
# objectified
# occupied
# occurred
# occurring
# offsetting
# omitted
# omitting
# ossified
# outbidden
# outbidding
# outbred
# outcried
# outcropped
# outcropping
# outdid
# outdone
# outdrawn
# outdrew
# outfitted
# outfitting
# outfought
# outgassed
# outgasses
# outgassing
# outgeneralled
# outgeneralling
# outgone
# outgrew
# outgrown
# outlaid
# outmanned
# outmanning
# outputted
# outputting
# outran
# outridden
# outrode
# outrunning
# outshone
# outshot
# outsold
# outspanned
# outspanning
# outstood
# outstripped
# outstripping
# outthought
# outwent
# outwitted
# outwitting
# outwore
# outworn
# overbidden
# overbidding
# overblew
# overblown
# overbore
# overborne
# overbuilt
# overcame
# overcropped
# overcropping
# overdid
# overdone
# overdrawn
# overdrew
# overdriven
# overdrove
# overflew
# overflown
# overgrew
# overgrown
# overheard
# overhung
# overlaid
# overlain
# overlapped
# overlapping
# overlay
# overlying
# overmanned
# overmanning
# overpaid
# overpast
# overran
# overridden
# overrode
# overrunning
# oversaw
# overseen
# oversetting
# oversewn
# overshot
# oversimplified
# overslept
# oversold
# overspent
# overspilt
# overstepped
# overstepping
# overtaken
# overthrew
# overthrown
# overtook
# overtopped
# overtopping
# overwound
# overwritten
# overwrote
# pacified
# padded
# padding
# paid
# palled
# palling
# palsied
# pandied
# panelled
# panelling
# panicked
# panicking
# panned
# panning
# parallelled
# parallelling
# parcelled
# parcelling
# parodied
# parried
# partaken
# partook
# pasquil
# pasquilled
# pasquilling
# pasquils
# patrolled
# patrolling
# patted
# patting
# pedalled
# pedalling
# pegged
# pegging
# pencilled
# pencilling
# penned
# penning
# pent
# pepped
# pepping
# permitted
# permitting
# personified
# petrified
# petted
# pettifogged
# pettifogging
# petting
# phantasied
# photocopied
# photomapped
# photomapping
# photosetting
# physicked
# physicking
# picnicked
# picnicking
# pigged
# pigging
# pilloried
# pinch-hitting
# pinned
# pinning
# pipped
# pipping
# pistol-whipped
# pistol-whipping
# pistolled
# pistolling
# pitapatted
# pitapatting
# pitied
# pitted
# pitting
# planned
# planning
# platted
# platting
# played_a_part
# playing_a_part
# plays_a_part
# pled
# plied
# plodded
# plodding
# plopped
# plopping
# plotted
# plotting
# plugged
# plugging
# podded
# podding
# pommelled
# pommelling
# popes
# popped
# popping
# potted
# potting
# preachified
# precancelled
# precancelling
# preferred
# preferring
# preoccupied
# prepaid
# presignified
# pretermitted
# pretermitting
# prettied
# prettified
# pried
# prigged
# prigging
# primmed
# primming
# prodded
# prodding
# programmed
# programmes
# programming
# prologed
# prologing
# prologs
# propelled
# propelling
# prophesied
# propped
# propping
# proven
# pubbed
# pubbing
# pugged
# pugging
# pummelled
# pummelling
# punned
# punning
# pupped
# pupping
# purified
# put-putted
# put-putting
# putrefied
# puttied
# putting
# qualified
# quantified
# quarrelled
# quarrelling
# quarried
# quartersawn
# queried
# quick-froze
# quick-frozen
# quickstepped
# quickstepping
# quipped
# quipping
# quitted
# quitting
# quizzed
# quizzes
# quizzing
# ragged
# ragging
# rallied
# ramified
# rammed
# ramming
# ran
# rang
# rapped
# rappelled
# rappelling
# rapping
# rarefied
# ratified
# ratted
# ratting
# ravelled
# ravelling
# razor-cutting
# re-trod
# re-trodden
# rebelled
# rebelling
# rebuilt
# rebutted
# rebutting
# recapped
# recapping
# reclassified
# recommitted
# recommitting
# recopied
# rectified
# recurred
# recurring
# red
# red-pencilled
# red-pencilling
# redded
# redding
# redid
# redone
# referred
# referring
# refitted
# refitting
# reft
# refuelled
# refuelling
# regretted
# regretting
# reheard
# reified
# relied
# remade
# remarried
# remitted
# remitting
# rent
# repaid
# repelled
# repelling
# replevied
# replied
# repotted
# repotting
# reran
# rerunning
# resat
# resetting
# resewn
# resitting
# retaken
# rethought
# retold
# retook
# retransmitted
# retransmitting
# retried
# retrofitted
# retrofitting
# retted
# retting
# reunified
# revelled
# revelling
# revetted
# revetting
# revivified
# revved
# revving
# rewound
# rewritten
# rewrote
# ribbed
# ribbing
# ricochetted
# ricochetting
# ridded
# ridden
# ridding
# rigged
# rigging
# rigidified
# rimmed
# rimming
# ripped
# ripping
# risen
# rivalled
# rivalling
# riven
# robbed
# robbing
# rode
# rose
# rotted
# rotting
# rough-dried
# rough-hewn
# rove
# rowelled
# rowelling
# rubbed
# rubbing
# rung
# running
# rutted
# rutting
# saccharified
# sagged
# sagging
# said
# salaried
# salified
# sallied
# sanctified
# sandbagged
# sandbagging
# sang
# sank
# saponified
# sapped
# sapping
# sat
# satisfied
# savvied
# saw
# sawn
# scagged
# scagging
# scanned
# scanning
# scarified
# scarred
# scarring
# scatted
# scatting
# scorified
# scragged
# scragging
# scrammed
# scramming
# scrapped
# scrapping
# scried
# scrubbed
# scrubbing
# scrummed
# scrumming
# scudded
# scudding
# scummed
# scumming
# scurried
# seed
# seen
# sent
# setting
# sewn
# shagged
# shagging
# shaken
# shaken_hands
# shakes_hands
# shaking_hands
# shammed
# shamming
# sharecropped
# sharecropping
# shat
# shaven
# shed
# shedding
# shellacked
# shellacking
# shent
# shewn
# shied
# shikarred
# shikarring
# shillyshallied
# shimmed
# shimmied
# shimming
# shinned
# shinning
# shipped
# shipping
# shitted
# shitting
# shod
# shone
# shook
# shook_hands
# shopped
# shopping
# shot
# shotgunned
# shotgunning
# shotted
# shotting
# shovelled
# shovelling
# shown
# shrank
# shredded
# shredding
# shrink-wrapped
# shrink-wrapping
# shrivelled
# shrivelling
# shriven
# shrove
# shrugged
# shrugging
# shrunk
# shrunken
# shunned
# shunning
# shutting
# sicked
# sicking
# sideslipped
# sideslipping
# sidestepped
# sidestepping
# sightsaw
# sightseen
# signalled
# signalling
# signified
# silicified
# simplified
# singing
# single-stepped
# single-stepping
# sinned
# sinning
# sipped
# sipping
# sitting
# skellied
# skenned
# skenning
# sketted
# sketting
# ski'd
# skidded
# skidding
# skimmed
# skimming
# skin-popped
# skin-popping
# skinned
# skinning
# skinny-dipped
# skinny-dipping
# skipped
# skipping
# skivvied
# skydove
# slabbed
# slabbing
# slagged
# slagging
# slain
# slammed
# slamming
# slapped
# slapping
# slatted
# slatting
# sledding
# slept
# slew
# slid
# slidden
# slipped
# slipping
# slitting
# slogged
# slogging
# slopped
# slopping
# slotted
# slotting
# slugged
# slugging
# slummed
# slumming
# slung
# slunk
# slurred
# slurring
# smelt
# smit
# smitten
# smote
# smutted
# smutting
# snagged
# snagging
# snapped
# snapping
# snedded
# snedding
# snipped
# snipping
# snivelled
# snivelling
# snogged
# snogging
# snubbed
# snubbing
# snuck
# snugged
# snugging
# sobbed
# sobbing
# sodded
# sodding
# soft-pedalled
# soft-pedalling
# sold
# solemnified
# solidified
# soothsaid
# sopped
# sopping
# sought
# sown
# spagged
# spagging
# spancelled
# spancelling
# spanned
# spanning
# sparred
# sparring
# spat
# spatted
# spatting
# specified
# sped
# speechified
# spellbound
# spelt
# spent
# spied
# spilt
# spin-dried
# spinning
# spiralled
# spiralling
# spitted
# spitting
# splitting
# spoilt
# spoke
# spoken
# spoon-fed
# spotlit
# spotted
# spotting
# sprang
# sprigged
# sprigging
# sprung
# spudded
# spudding
# spun
# spurred
# spurring
# squatted
# squatting
# squibbed
# squibbing
# squidded
# squidding
# squilgee
# stabbed
# stabbing
# stall-fed
# stank
# starred
# starring
# steadied
# stellified
# stemmed
# stemming
# stems_from
# stencilled
# stencilling
# stepped
# stepping
# stetted
# stetting
# stied
# stilettoeing
# stirred
# stirring
# stole
# stolen
# stood
# stopped
# stopping
# storied
# stotted
# stotting
# stove
# strapped
# strapping
# stratified
# strewn
# stridden
# stripped
# stripping
# striven
# strode
# stropped
# stropping
# strove
# strown
# struck
# strummed
# strumming
# strung
# strutted
# strutting
# stubbed
# stubbing
# stuck
# studded
# studding
# studied
# stultified
# stummed
# stumming
# stung
# stunk
# stunned
# stunning
# stupefied
# stymying
# subbed
# subbing
# subjectified
# subletting
# submitted
# submitting
# subtotalled
# subtotalling
# sullied
# sulphuretted
# sulphuretting
# summed
# summing
# sung
# sunk
# sunken
# sunned
# sunning
# supped
# supping
# supplied
# swabbed
# swabbing
# swagged
# swagging
# swam
# swapped
# swapping
# swatted
# swatting
# swept
# swigged
# swigging
# swimming
# swivelled
# swivelling
# swollen
# swopped
# swopping
# swops
# swore
# sworn
# swotted
# swotting
# swum
# swung
# syllabified
# symbolled
# symbolling
# tabbed
# tabbing
# tagged
# tagging
# taken
# taken_a_side
# taken_pains
# taken_steps
# takes_a_side
# takes_pains
# takes_steps
# taking_a_side
# taking_pains
# taking_steps
# talcked
# talcking
# tallied
# tally-ho'd
# tammied
# tanned
# tanning
# tapped
# tapping
# tarred
# tarried
# tarring
# tasselled
# tasselling
# tatted
# tatting
# taught
# taxis
# taxying
# teaselled
# teaselling
# tedded
# tedding
# tepefied
# terrified
# testes
# testified
# thinking_the_world_of
# thinks_the_world_of
# thinned
# thinning
# thought
# thought_the_world_of
# threw
# threw_out
# thriven
# throbbed
# throbbing
# throve
# throwing_out
# thrown
# thrown_out
# throws_out
# thrummed
# thrumming
# thudded
# thudding
# tidied
# tinned
# tinning
# tinselled
# tinselling
# tipped
# tipping
# tittupped
# tittupping
# toadied
# togged
# togging
# told
# took
# took_a_side
# took_pains
# took_steps
# topped
# topping
# tore
# torn
# torrefied
# torrify
# totalled
# totalling
# totted
# totting
# towelled
# towelling
# trafficked
# trafficking
# trameled
# trameling
# tramelled
# tramelling
# tramels
# trammed
# tramming
# transferred
# transferring
# transfixt
# tranship
# transhipped
# transhipping
# transmitted
# transmitting
# transmogrified
# transshipped
# transshipping
# trapanned
# trapanning
# trapped
# trapping
# travelled
# travelling
# travestied
# trekked
# trekking
# trepanned
# trepanning
# tried
# trigged
# trigging
# trimmed
# trimming
# tripped
# tripping
# trod
# trodden
# trogged
# trogging
# trotted
# trotting
# trowelled
# trowelling
# tugged
# tugging
# tumefied
# tunned
# tunnelled
# tunnelling
# tunning
# tupped
# tupping
# tut-tutted
# tut-tutting
# twigged
# twigging
# twinned
# twinning
# twitted
# twitting
# tying
# typesetting
# typewritten
# typewrote
# typified
# uglified
# unbarred
# unbarring
# unbent
# unbound
# uncapped
# uncapping
# unclad
# unclogged
# unclogging
# underbidding
# underbought
# undercutting
# underfed
# undergirt
# undergone
# underlaid
# underlain
# underlay
# underletting
# underlying
# underpaid
# underpinned
# underpinning
# underpropped
# underpropping
# undersetting
# undershot
# undersold
# understood
# understudied
# undertaken
# undertook
# underwent
# underwritten
# underwrote
# undid
# undone
# unfitted
# unfitting
# unfroze
# unfrozen
# unified
# unkennelled
# unkennelling
# unknitted
# unknitting
# unlaid
# unlearnt
# unmade
# unmanned
# unmanning
# unpegged
# unpegging
# unpinned
# unpinning
# unplugged
# unplugging
# unravelled
# unravelling
# unrigged
# unrigging
# unripped
# unripping
# unrove
# unsaid
# unshipped
# unshipping
# unslung
# unsnapped
# unsnapping
# unspoke
# unspoken
# unsteadied
# unstepped
# unstepping
# unstopped
# unstopping
# unstrung
# unstuck
# unswore
# unsworn
# untaught
# unthought
# untidied
# untrod
# untrodden
# untying
# unwound
# unwrapped
# unwrapping
# unzipped
# unzipping
# upbuilt
# upheld
# uphove
# upped
# uppercutting
# upping
# uprisen
# uprose
# upsetting
# upsprang
# upsprung
# upswept
# upswollen
# upswung
# vagged
# vagging
# varied
# vatted
# vatting
# verbified
# verified
# versified
# vetted
# vetting
# victualled
# victualling
# vilified
# vitrified
# vitriolled
# vitriolling
# vivified
# vying
# wadded
# waddied
# wadding
# wadsetted
# wadsetting
# wagged
# wagging
# wanned
# wanning
# warred
# warring
# was
# water-ski'd
# waylaid
# wearied
# weatherstripped
# weatherstripping
# webbed
# webbing
# wedded
# wedding
# weed
# went
# went_deep
# wept
# were
# wetted
# wetting
# whammed
# whamming
# whapped
# whapping
# whetted
# whetting
# whinnied
# whipped
# whipping
# whipsawn
# whirred
# whirring
# whistle-stopped
# whistle-stopping
# whizzed
# whizzes
# whizzing
# whopped
# whopping
# wigged
# wigging
# wigwagged
# wigwagging
# wildcatted
# wildcatting
# window-shopped
# window-shopping
# winning
# winterfed
# wiredrawn
# wiredrew
# withdrawn
# withdrew
# withheld
# withstood
# woke
# woken
# won
# wonned
# wonning
# wore
# worn
# worried
# worshipped
# worshipping
# wound
# wove
# woven
# wrapped
# wrapping
# wried
# written
# wrote
# wrought
# wrung
# yakked
# yakking
# yapped
# yapping
# ycleped
# yclept
# yenned
# yenning
# yodelled
# yodelling
# zapped
# zapping
# zigzagged
# zigzagging
# zipped
# zipping
# adj.exc
# acer
# after
# airier
# airiest
# all-arounder
# angrier
# angriest
# archer
# artier
# artiest
# ashier
# ashiest
# assaulter
# attacker
# backer
# baggier
# baggiest
# balkier
# balkiest
# balmier
# balmiest
# bandier
# bandiest
# bargainer
# barmier
# barmiest
# battier
# battiest
# baulkier
# baulkiest
# bawdier
# bawdiest
# bayer
# beadier
# beadiest
# beastlier
# beastliest
# beater
# beefier
# beefiest
# beerier
# beeriest
# bendier
# bendiest
# best
# better
# bigger
# biggest
# bitchier
# bitchiest
# biter
# bittier
# bittiest
# blearier
# bleariest
# bloodier
# bloodiest
# bloodthirstier
# bloodthirstiest
# blowier
# blowiest
# blowsier
# blowsiest
# blowzier
# blowziest
# bluer
# bluest
# boner
# bonier
# boniest
# bonnier
# bonniest
# boozier
# booziest
# boskier
# boskiest
# bossier
# bossiest
# botchier
# botchiest
# bother
# bouncier
# bounciest
# bounder
# bower
# brainier
# brainiest
# brashier
# brashiest
# brassier
# brassiest
# brawnier
# brawniest
# breathier
# breathiest
# breezier
# breeziest
# brinier
# briniest
# britisher
# broadcaster
# brooder
# broodier
# broodiest
# bubblier
# bubbliest
# buggier
# buggiest
# bulkier
# bulkiest
# bumpier
# bumpiest
# bunchier
# bunchiest
# burlier
# burliest
# burrier
# burriest
# burster
# bushier
# bushiest
# busier
# busiest
# buster
# bustier
# bustiest
# cagier
# cagiest
# camper
# cannier
# canniest
# canter
# cantier
# cantiest
# caster
# catchier
# catchiest
# cattier
# cattiest
# cer
# chancier
# chanciest
# charier
# chariest
# chattier
# chattiest
# cheekier
# cheekiest
# cheerier
# cheeriest
# cheesier
# cheesiest
# chestier
# chestiest
# chewier
# chewiest
# chillier
# chilliest
# chintzier
# chintziest
# chippier
# chippiest
# choosier
# choosiest
# choppier
# choppiest
# chubbier
# chubbiest
# chuffier
# chuffiest
# chummier
# chummiest
# chunkier
# chunkiest
# churchier
# churchiest
# clammier
# clammiest
# classier
# classiest
# cleanlier
# cleanliest
# clerklier
# clerkliest
# cloudier
# cloudiest
# clubbier
# clubbiest
# clumsier
# clumsiest
# cockier
# cockiest
# coder
# collier
# colliest
# comelier
# comeliest
# comfier
# comfiest
# cornier
# corniest
# cosier
# cosiest
# costlier
# costliest
# costumer
# counterfeiter
# courtlier
# courtliest
# cozier
# coziest
# crabbier
# crabbiest
# cracker
# craftier
# craftiest
# craggier
# craggiest
# crankier
# crankiest
# crasher
# crawlier
# crawliest
# crazier
# craziest
# creamer
# creamier
# creamiest
# creepier
# creepiest
# crispier
# crispiest
# crumbier
# crumbiest
# crumblier
# crumbliest
# crummier
# crummiest
# crustier
# crustiest
# curlier
# curliest
# customer
# cuter
# daffier
# daffiest
# daintier
# daintiest
# dandier
# dandiest
# deadlier
# deadliest
# dealer
# deserter
# dewier
# dewiest
# dicier
# diciest
# dimer
# dimmer
# dimmest
# dingier
# dingiest
# dinkier
# dinkiest
# dippier
# dippiest
# dirtier
# dirtiest
# dishier
# dishiest
# dizzier
# dizziest
# dodgier
# dodgiest
# dopier
# dopiest
# dottier
# dottiest
# doughier
# doughiest
# doughtier
# doughtiest
# dowdier
# dowdiest
# dowier
# dowiest
# downer
# downier
# downiest
# dozier
# doziest
# drabber
# drabbest
# draftier
# draftiest
# draggier
# draggiest
# draughtier
# draughtiest
# dreamier
# dreamiest
# drearier
# dreariest
# dreggier
# dreggiest
# dresser
# dressier
# dressiest
# drier
# driest
# drippier
# drippiest
# drowsier
# drowsiest
# dryer
# dryest
# dumpier
# dumpiest
# dunner
# dunnest
# duskier
# duskiest
# dustier
# dustiest
# earlier
# earliest
# earthier
# earthiest
# earthlier
# earthliest
# easier
# easiest
# easter
# eastsider
# edger
# edgier
# edgiest
# eerier
# eeriest
# emptier
# emptiest
# faker
# fancier
# fanciest
# fatter
# fattest
# fattier
# fattiest
# faultier
# faultiest
# feistier
# feistiest
# feller
# fiddlier
# fiddliest
# filmier
# filmiest
# filthier
# filthiest
# finnier
# finniest
# first-rater
# first-stringer
# fishier
# fishiest
# fitter
# fittest
# flabbier
# flabbiest
# flaggier
# flaggiest
# flakier
# flakiest
# flasher
# flashier
# flashiest
# flatter
# flattest
# flauntier
# flauntiest
# fledgier
# fledgiest
# fleecier
# fleeciest
# fleshier
# fleshiest
# fleshlier
# fleshliest
# flightier
# flightiest
# flimsier
# flimsiest
# flintier
# flintiest
# floatier
# floatiest
# floppier
# floppiest
# flossier
# flossiest
# fluffier
# fluffiest
# flukier
# flukiest
# foamier
# foamiest
# foggier
# foggiest
# folder
# folksier
# folksiest
# foolhardier
# foolhardiest
# fore-and-after
# foreigner
# forest
# founder
# foxier
# foxiest
# fratchier
# fratchiest
# freakier
# freakiest
# freer
# freest
# frenchier
# frenchiest
# friendlier
# friendliest
# friskier
# friskiest
# frizzier
# frizziest
# frizzlier
# frizzliest
# frostier
# frostiest
# frouzier
# frouziest
# frowsier
# frowsiest
# frowzier
# frowziest
# fruitier
# fruitiest
# funkier
# funkiest
# funnier
# funniest
# furrier
# furriest
# fussier
# fussiest
# fustier
# fustiest
# fuzzier
# fuzziest
# gabbier
# gabbiest
# gamier
# gamiest
# gammier
# gammiest
# gassier
# gassiest
# gaudier
# gaudiest
# gauzier
# gauziest
# gawkier
# gawkiest
# ghastlier
# ghastliest
# ghostlier
# ghostliest
# giddier
# giddiest
# gladder
# gladdest
# glassier
# glassiest
# glibber
# glibbest
# gloomier
# gloomiest
# glossier
# glossiest
# glummer
# glummest
# godlier
# godliest
# goer
# goner
# goodlier
# goodliest
# goofier
# goofiest
# gooier
# gooiest
# goosier
# goosiest
# gorier
# goriest
# gradelier
# gradeliest
# grader
# grainier
# grainiest
# grassier
# grassiest
# greasier
# greasiest
# greedier
# greediest
# grimmer
# grimmest
# grislier
# grisliest
# grittier
# grittiest
# grizzlier
# grizzliest
# groggier
# groggiest
# groovier
# grooviest
# grottier
# grottiest
# grounder
# grouper
# groutier
# groutiest
# grubbier
# grubbiest
# grumpier
# grumpiest
# guest
# guiltier
# guiltiest
# gummier
# gummiest
# gushier
# gushiest
# gustier
# gustiest
# gutsier
# gutsiest
# hairier
# hairiest
# halfways
# halter
# hammier
# hammiest
# handier
# handiest
# happier
# happiest
# hardier
# hardiest
# hastier
# hastiest
# haughtier
# haughtiest
# hazier
# haziest
# header
# headier
# headiest
# healthier
# healthiest
# heartier
# heartiest
# heavier
# heaviest
# heftier
# heftiest
# hepper
# heppest
# herbier
# herbiest
# hinder
# hipper
# hippest
# hippier
# hippiest
# hoarier
# hoariest
# holier
# holiest
# homelier
# homeliest
# homer
# homier
# homiest
# hornier
# horniest
# horsier
# horsiest
# hotter
# hottest
# humpier
# humpiest
# hunger
# hungrier
# hungriest
# huskier
# huskiest
# icier
# iciest
# inkier
# inkiest
# insider
# interest
# jaggier
# jaggiest
# jammier
# jammiest
# jauntier
# jauntiest
# jazzier
# jazziest
# jerkier
# jerkiest
# jointer
# jollier
# jolliest
# juicier
# juiciest
# jumpier
# jumpiest
# kindlier
# kindliest
# kinkier
# kinkiest
# knottier
# knottiest
# knurlier
# knurliest
# kookier
# kookiest
# lacier
# laciest
# lairier
# lairiest
# lakier
# lakiest
# lander
# lankier
# lankiest
# lathier
# lathiest
# layer
# lazier
# laziest
# leafier
# leafiest
# leakier
# leakiest
# learier
# leariest
# leer
# leerier
# leeriest
# left-hander
# left-winger
# leggier
# leggiest
# lengthier
# lengthiest
# ler
# leveler
# limier
# limiest
# lippier
# lippiest
# liter
# livelier
# liveliest
# liver
# loather
# loftier
# loftiest
# logier
# logiest
# lonelier
# loneliest
# loner
# loonier
# looniest
# loopier
# loopiest
# lordlier
# lordliest
# lousier
# lousiest
# lovelier
# loveliest
# lowlander
# lowlier
# lowliest
# luckier
# luckiest
# lumpier
# lumpiest
# lunier
# luniest
# lustier
# lustiest
# madder
# maddest
# mainer
# maligner
# maltier
# maltiest
# mangier
# mangiest
# mankier
# mankiest
# manlier
# manliest
# mariner
# marshier
# marshiest
# massier
# massiest
# matter
# maungier
# maungiest
# mazier
# maziest
# mealier
# mealiest
# measlier
# measliest
# meatier
# meatiest
# meeter
# merrier
# merriest
# messier
# messiest
# miffier
# miffiest
# mightier
# mightiest
# milcher
# milker
# milkier
# milkiest
# mingier
# mingiest
# minter
# mirkier
# mirkiest
# miser
# mistier
# mistiest
# mocker
# modeler
# modest
# moldier
# moldiest
# moodier
# moodiest
# moonier
# mooniest
# mothier
# mothiest
# mouldier
# mouldiest
# mousier
# mousiest
# mouthier
# mouthiest
# muckier
# muckiest
# muddier
# muddiest
# muggier
# muggiest
# multiplexer
# murkier
# murkiest
# mushier
# mushiest
# muskier
# muskiest
# muster
# mustier
# mustiest
# muzzier
# muzziest
# nappier
# nappiest
# nastier
# nastiest
# nattier
# nattiest
# naughtier
# naughtiest
# needier
# neediest
# nervier
# nerviest
# newsier
# newsiest
# niftier
# niftiest
# nippier
# nippiest
# nittier
# nittiest
# noisier
# noisiest
# northeasterner
# norther
# northerner
# nosier
# nosiest
# number
# nuttier
# nuttiest
# offer
# offer
# oilier
# oiliest
# old-timer
# oliver
# oozier
# ooziest
# opener
# outsider
# overcomer
# overnighter
# owner
# pallier
# palliest
# palmier
# palmiest
# paltrier
# paltriest
# pappier
# pappiest
# parkier
# parkiest
# part-timer
# passer
# paster
# pastier
# pastiest
# patchier
# patchiest
# pater
# pawkier
# pawkiest
# peachier
# peachiest
# pearler
# pearlier
# pearliest
# pedaler
# peppier
# peppiest
# perkier
# perkiest
# peskier
# peskiest
# peter
# pettier
# pettiest
# phonier
# phoniest
# pickier
# pickiest
# piggier
# piggiest
# pinier
# piniest
# pitchier
# pitchiest
# pithier
# pithiest
# planer
# plashier
# plashiest
# platier
# platiest
# player
# pluckier
# pluckiest
# plumber
# plumier
# plumiest
# plummier
# plummiest
# podgier
# podgiest
# pokier
# pokiest
# polisher
# porkier
# porkiest
# porter
# portlier
# portliest
# poster
# pottier
# pottiest
# preachier
# preachiest
# presenter
# pretender
# prettier
# prettiest
# pricier
# priciest
# pricklier
# prickliest
# priestlier
# priestliest
# primer
# primmer
# primmest
# princelier
# princeliest
# printer
# prissier
# prissiest
# privateer
# privier
# priviest
# prompter
# prosier
# prosiest
# pudgier
# pudgiest
# puffer
# puffier
# puffiest
# pulpier
# pulpiest
# punchier
# punchiest
# punier
# puniest
# pushier
# pushiest
# pussier
# pussiest
# quaggier
# quaggiest
# quakier
# quakiest
# queasier
# queasiest
# queenlier
# queenliest
# racier
# raciest
# rainier
# rainiest
# randier
# randiest
# rangier
# rangiest
# ranker
# rattier
# rattiest
# rattlier
# rattliest
# raunchier
# raunchiest
# readier
# readiest
# recorder
# redder
# reddest
# reedier
# reediest
# renter
# retailer
# right-hander
# right-winger
# rimier
# rimiest
# riskier
# riskiest
# ritzier
# ritziest
# roaster
# rockier
# rockiest
# roilier
# roiliest
# rookier
# rookiest
# roomier
# roomiest
# ropier
# ropiest
# rosier
# rosiest
# rowdier
# rowdiest
# ruddier
# ruddiest
# runnier
# runniest
# rusher
# rushier
# rushiest
# rustier
# rustiest
# ruttier
# ruttiest
# sadder
# saddest
# salter
# saltier
# saltiest
# sampler
# sandier
# sandiest
# sappier
# sappiest
# sassier
# sassiest
# saucier
# sauciest
# savvier
# savviest
# scabbier
# scabbiest
# scalier
# scaliest
# scantier
# scantiest
# scarier
# scariest
# scraggier
# scraggiest
# scragglier
# scraggliest
# scraper
# scrappier
# scrappiest
# scrawnier
# scrawniest
# screwier
# screwiest
# scrubbier
# scrubbiest
# scruffier
# scruffiest
# scungier
# scungiest
# scurvier
# scurviest
# seamier
# seamiest
# second-rater
# seconder
# seedier
# seediest
# seemlier
# seemliest
# serer
# sexier
# sexiest
# shabbier
# shabbiest
# shadier
# shadiest
# shaggier
# shaggiest
# shakier
# shakiest
# shapelier
# shapeliest
# shier
# shiest
# shiftier
# shiftiest
# shinier
# shiniest
# shirtier
# shirtiest
# shoddier
# shoddiest
# showier
# showiest
# shrubbier
# shrubbiest
# shyer
# shyest
# sicklier
# sickliest
# sightlier
# sightliest
# signaler
# signer
# silkier
# silkiest
# sillier
# silliest
# sketchier
# sketchiest
# skewer
# skimpier
# skimpiest
# skinnier
# skinniest
# slaphappier
# slaphappiest
# slatier
# slatiest
# slaver
# sleazier
# sleaziest
# sleepier
# sleepiest
# slier
# sliest
# slimier
# slimiest
# slimmer
# slimmest
# slimsier
# slimsiest
# slinkier
# slinkiest
# slippier
# slippiest
# sloppier
# sloppiest
# slyer
# slyest
# smarmier
# smarmiest
# smellier
# smelliest
# smokier
# smokiest
# smugger
# smuggest
# snakier
# snakiest
# snappier
# snappiest
# snatchier
# snatchiest
# snazzier
# snazziest
# sneaker
# sniffier
# sniffiest
# snootier
# snootiest
# snottier
# snottiest
# snowier
# snowiest
# snuffer
# snuffier
# snuffiest
# snugger
# snuggest
# soapier
# soapiest
# soggier
# soggiest
# solder
# sonsier
# sonsiest
# sootier
# sootiest
# soppier
# soppiest
# sorrier
# sorriest
# soupier
# soupiest
# souther
# southerner
# speedier
# speediest
# spicier
# spiciest
# spiffier
# spiffiest
# spikier
# spikiest
# spindlier
# spindliest
# spinier
# spiniest
# splashier
# splashiest
# spongier
# spongiest
# spookier
# spookiest
# spoonier
# spooniest
# sportier
# sportiest
# spottier
# spottiest
# spreader
# sprier
# spriest
# sprightlier
# sprightliest
# springer
# springier
# springiest
# squashier
# squashiest
# squatter
# squattest
# squattier
# squattiest
# squiffier
# squiffiest
# stagier
# stagiest
# stalkier
# stalkiest
# stapler
# starchier
# starchiest
# starer
# starest
# starrier
# starriest
# statelier
# stateliest
# steadier
# steadiest
# stealthier
# stealthiest
# steamier
# steamiest
# stingier
# stingiest
# stiper
# stocker
# stockier
# stockiest
# stodgier
# stodgiest
# stonier
# stoniest
# stormier
# stormiest
# streakier
# streakiest
# streamier
# streamiest
# stretcher
# stretchier
# stretchiest
# stringier
# stringiest
# stripier
# stripiest
# stronger
# strongest
# stroppier
# stroppiest
# stuffier
# stuffiest
# stumpier
# stumpiest
# sturdier
# sturdiest
# submariner
# sulkier
# sulkiest
# sultrier
# sultriest
# sunnier
# sunniest
# surlier
# surliest
# swagger
# swankier
# swankiest
# swarthier
# swarthiest
# sweatier
# sweatiest
# tackier
# tackiest
# talkier
# talkiest
# tangier
# tangiest
# tanner
# tannest
# tardier
# tardiest
# tastier
# tastiest
# tattier
# tattiest
# tawdrier
# tawdriest
# techier
# techiest
# teenager
# teenier
# teeniest
# teetotaler
# tester
# testier
# testiest
# tetchier
# tetchiest
# thinner
# thinnest
# third-rater
# thirstier
# thirstiest
# thornier
# thorniest
# threadier
# threadiest
# thriftier
# thriftiest
# throatier
# throatiest
# tidier
# tidiest
# timelier
# timeliest
# tinier
# tiniest
# tinnier
# tinniest
# tipsier
# tipsiest
# tonier
# toniest
# toothier
# toothiest
# toper
# touchier
# touchiest
# trader
# trashier
# trashiest
# trendier
# trendiest
# trickier
# trickiest
# tricksier
# tricksiest
# trimer
# trimmer
# trimmest
# truer
# truest
# trustier
# trustiest
# tubbier
# tubbiest
# turfier
# turfiest
# tweedier
# tweediest
# twiggier
# twiggiest
# uglier
# ugliest
# unfriendlier
# unfriendliest
# ungainlier
# ungainliest
# ungodlier
# ungodliest
# unhappier
# unhappiest
# unhealthier
# unhealthiest
# unholier
# unholiest
# unrulier
# unruliest
# untidier
# untidiest
# vastier
# vastiest
# vest
# viewier
# viewiest
# wackier
# wackiest
# wanner
# wannest
# warier
# wariest
# washier
# washiest
# waster
# wavier
# waviest
# waxier
# waxiest
# weaklier
# weakliest
# wealthier
# wealthiest
# wearier
# weariest
# webbier
# webbiest
# weedier
# weediest
# weenier
# weeniest
# weensier
# weensiest
# weepier
# weepiest
# weightier
# weightiest
# welsher
# wetter
# wettest
# whackier
# whackiest
# whimsier
# whimsiest
# wholesaler
# wieldier
# wieldiest
# wilier
# wiliest
# windier
# windiest
# winier
# winiest
# winterier
# winteriest
# wintrier
# wintriest
# wirier
# wiriest
# wispier
# wispiest
# wittier
# wittiest
# wonkier
# wonkiest
# woodier
# woodiest
# woodsier
# woodsiest
# woollier
# woolliest
# woozier
# wooziest
# wordier
# wordiest
# worldlier
# worldliest
# wormier
# wormiest
# worse
# worst
# worthier
# worthiest
# wrier
# wriest
# wryer
# wryest
# yarer
# yarest
# yeastier
# yeastiest
# younger
# youngest
# yummier
# yummiest
# zanier
# zaniest
# zippier
# zippiest
# noun.exc
# aardwolves
# abaci
# aboideaux
# aboiteaux
# abscissae
# acanthi
# acari
# acciaccature
# acetabula
# achaemenidae
# achaemenides
# acicula
# aciculae
# acini
# acre-feet
# acromia
# actiniae
# actinozoa
# addenda
# adenocarcinomata
# adenomata
# adieux
# adyta
# aecia
# aecidia
# aerobia
# agents-general
# aggiornamenti
# agnomina
# agones
# agorae
# agouties
# aides-de-camp
# aides-memoire
# aids-de-camp
# alae
# alewives
# alkalies
# allodia
# alluvia
# alodia
# alto-relievos
# altocumuli
# altostrati
# alulae
# alumnae
# alumni
# alveoli
# amanuenses
# ambulacra
# amebae
# amici_curiae
# amnia
# amniocenteses
# amoebae
# amoebiases
# amoraim
# amoretti
# amorini
# amphiarthroses
# amphicia
# amphimixes
# amphioxi
# amphisbaenae
# amphorae
# ampullae
# amygdalae
# anabases
# anacolutha
# anacruses
# anaerobia
# anagnorises
# analemmata
# analyses
# anamneses
# anamorphoses
# anastomoses
# anatyxes
# ancones
# androclinia
# androecia
# androsphinges
# andtheridia
# angelfishes
# angiomata
# animalcula
# anlagen
# annattos
# annuli
# antae
# antalkalies
# antefixa
# antennae
# antependia
# anthelia
# anthelices
# anthemia
# antheridia
# anthodia
# anthozoa
# anthraces
# anticlinoria
# antihelices
# antiheroes
# antisera
# antitheses
# antitragi
# antra
# anus
# aortae
# aphelia
# aphides
# apices
# apodoses
# apomixes
# aponeuroses
# apophyses
# aposiopeses
# apothecia
# apotheoses
# apparatus
# appendices
# appoggiature
# apsides
# aquae
# aquaria
# araglis
# arboreta
# arcana
# archegonia
# archerfishes
# archesporia
# archipelagoes
# arcs-boutants
# areolae
# argali
# argumenta
# ariette
# aristae
# armamentaria
# arses
# artal
# artel
# arterioscleroses
# aruspices
# asceses
# asci
# ascidia
# ascogonia
# ashkenazim
# aspergilla
# aspergilli
# aspergilloses
# aspersoria
# assegais
# astragali
# asyndeta
# atheromata
# atheroscleroses
# atmolyses
# atria
# attorneys-at-law
# auditoria
# aurae
# aurar
# aurei
# auriculae
# aurorae
# auspices
# autocatalyses
# autochthones
# automata
# autos-da-fe
# avitaminoses
# axes
# axillae
# bacchantes
# bacchii
# bacilli
# bacteriostases
# bacula
# bains-marie
# bains_marie
# ballistae
# bambini
# bandeaux
# banditti
# bani
# banjoes
# barklice
# barramundies
# bases
# bases-on-balls
# bases_on_balls
# basidia
# basileis
# bassi
# bastinadoes
# bateaux
# batfishes
# beadsmen
# beaux
# beches-de-mer
# beeves
# behooves
# bersaglieri
# bhishties
# bibliothecae
# bicennaries
# bijoux
# bilboes
# billets-doux
# billfishes
# bimboes
# bisectrices
# blackfeet
# blackfishes
# blastemata
# blastulae
# blindfishes
# blowfishes
# bluefishes
# boarfishes
# bok
# boleti
# bolivares
# bolsheviki
# bonefishes
# bongoes
# bonitoes
# booklice
# bookshelves
# boraces
# borborygmi
# bordereaux
# botargoes
# box-kodaks
# boxfishes
# brachia
# brainchildren
# branchiae
# brants
# bravadoes
# bravoes
# bregmata
# brethren
# broadcast_media
# broadleaves
# bronchi
# brothers-in-law
# bryozoa
# buboes
# buckoes
# buckteeth
# buffaloes
# bullae
# bunde
# bureaux
# bureaux_de_change
# bursae
# bushbok
# bushboks
# busses
# butterfishes
# byssi
# cacti
# caducei
# caeca
# caesurae
# calami
# calathi
# calcanei
# calces
# calculi
# caldaria
# calices
# calicoes
# calli
# calves
# calyces
# cambia
# camerae
# canaliculi
# candelabra
# candlefishes
# canthi
# canulae
# canzoni
# capita
# capitula
# capricci
# carabinieri
# carbonadoes
# carcinomata
# cargoes
# carides
# carinae
# caroli
# carpi
# carpogonia
# carryings-on
# caryopses
# caryopsides
# castrati
# catabases
# cataclases
# cataloes
# catalyses
# catenae
# catfishes
# cathari
# cathexes
# cattaloes
# caudices
# caules
# cavatine
# cavefishes
# cavetti
# cavo-rilievi
# ceca
# cellae
# cembali
# centesimi
# centra
# cephalothoraces
# cercariae
# cercariiae
# cerci
# cerebella
# cerebra
# cervices
# cestuses
# cesurae
# chadarim
# chaetae
# chaises_longues
# chalazae
# challoth
# chalutzim
# chapaties
# chapatties
# chapeaux
# chasidim
# chassidim
# chateaux
# chazanim
# chedarim
# chefs-d'ouvre
# chelae
# chelicerae
# cherubim
# chevaux-de-frise
# chiasmata
# chiasmi
# children
# chillies
# chinese_eddoes
# chitarroni
# chlamydes
# chlamyses
# chondromata
# choragi
# choriambi
# choux
# chromonemata
# chrysalides
# chuvashes
# ciboria
# cicadae
# cicale
# cicatrices
# ciceroni
# cicisbei
# cilia
# cimices
# cineraria
# cingula
# cirri
# cirrocumuli
# cirrostrati
# ciscoes
# cisternae
# clani
# clanos
# claroes
# clepsydrae
# clinandria
# clingfishes
# clitella
# cloacae
# clostridia
# cloverleaves
# clypei
# coagula
# coalfishes
# cocci
# coccyges
# cochleae
# codfishes
# codices
# coelentera
# coenuri
# cognomina
# cola
# coleorhizae
# collegia
# colloquia
# colluvia
# collyria
# colones
# colossi
# columbaria
# columellae
# comae
# comatulae
# comedones
# comics
# commandoes
# concertanti
# concerti
# concerti_grossi
# concertini
# conchae
# condottieri
# condylomata
# confervae
# congii
# conidia
# conjunctivae
# conquistadores
# consortia
# contagia
# continua
# contralti
# conversazioni
# convolvuli
# cooks-general
# copulae
# corbiculae
# coria
# corneae
# cornua
# coronae
# corpora
# corpora_lutea
# corpora_striata
# corrigenda
# cortices
# cortinae
# corybantes
# coryphaei
# costae
# cothurni
# courts_martial
# couteaux
# cowfishes
# coxae
# cramboes
# crania
# crases
# crawfishes
# crayfishes
# credenda
# crematoria
# crescendi
# cribella
# crises
# crissa
# cristae
# criteria
# cruces
# crura
# crusadoes
# cruzadoes
# crying
# cryings
# ctenidia
# cubicula
# culices
# culpae
# culs-de-sac
# culti
# cumuli
# cumulonimbi
# cumulostrati
# curiae
# curricula
# custodes
# cutes
# cuticulae
# cuttlefishes
# cyclopes
# cycloses
# cylices
# cylikes
# cymae
# cymatia
# cypselae
# cysticerci
# dadoes
# dagoes
# damselfishes
# data
# daughters-in-law
# daymio
# daymios
# dealfishes
# decemviri
# decennia
# deciduae
# definienda
# definientia
# delphinia
# denarii
# dentalia
# dermatoses
# desiderata
# desperadoes
# devilfishes
# diaereses
# diaerses
# diagnoses
# dialyses
# diaphyses
# diapophyses
# diarthroses
# diastalses
# diastases
# diastemata
# diathses
# diazoes
# dibbukkim
# dichasia
# dicta
# didoes
# diereses
# dieses
# differentiae
# dilettanti
# diluvia
# dingoes
# diplococci
# directors-general
# disci
# discoboli
# dive
# diverticula
# divertimenti
# djinn
# dodoes
# dogfishes
# dogmata
# dogteeth
# dollarfishes
# domatia
# dominoes
# dormice
# dorsa
# drachmae
# drawknives
# drosophilae
# drumfishes
# dryades
# dui
# duona
# duonas
# dupondii
# duumviri
# dwarves
# dybbukkim
# ecchymoses
# ecclesiae
# ecdyses
# echidnae
# echini
# echinococci
# echoes
# ectozoa
# eddoes
# edemata
# effluvia
# eidola
# eisegeses
# eisteddfodau
# elenchi
# ellipses
# eluvia
# elves
# elytra
# embargoes
# emboli
# emphases
# emporia
# enarthroses
# encephala
# encephalitides
# encephalomata
# enchiridia
# enchondromata
# encomia
# endamebae
# endamoebae
# endocardia
# endocrania
# endometria
# endostea
# endostoses
# endothecia
# endothelia
# endotheliomata
# endozoa
# enemata
# enneahedra
# entamebae
# entamoebae
# entases
# entera
# entia
# entozoa
# epencephala
# epentheses
# epexegeses
# ephemera
# ephemerae
# ephemerides
# ephori
# epicalyces
# epicanthi
# epicardia
# epicedia
# epicleses
# epididymides
# epigastria
# epiglottides
# epimysia
# epiphenomena
# epiphyses
# episterna
# epithalamia
# epithelia
# epitheliomata
# epizoa
# epyllia
# equilibria
# equiseta
# eringoes
# errata
# eryngoes
# esophagi
# etyma
# eucalypti
# eupatridae
# euripi
# exanthemata
# executrices
# exegeses
# exempla
# exordia
# exostoses
# extrema
# eyeteeth
# fabliaux
# faciae
# faculae
# faeroese
# fallfishes
# famuli
# farmers-general
# faroese
# farragoes
# fasciae
# fasciculi
# fathers-in-law
# fatsoes
# faunae
# feculae
# fedayeen
# feet
# fellaheen
# fellahin
# felones_de_se
# felos_de_se
# femora
# fenestellae
# fenestrae
# feriae
# fermate
# ferulae
# festschriften
# fetiales
# fezzes
# fiascoes
# fibrillae
# fibromata
# fibulae
# ficoes
# fideicommissa
# fieldmice
# figs.
# fila
# filariiae
# filefishes
# fimbriae
# fishes
# fishwives
# fistulae
# flabella
# flagella
# flagstaves
# flambeaux
# flamines
# flamingoes
# flatfeet
# flatfishes
# fleurs-de-lis
# fleurs-de-lys
# flights_of_stairs
# flittermice
# flocci
# flocculi
# florae
# floreant.
# florilegia
# flowers-de-luce
# flyleaves
# foci
# folia
# fora
# foramina
# forceps
# forefeet
# foreteeth
# formicaria
# formulae
# fornices
# fortes
# fossae
# foveae
# foveolae
# fractocumuli
# fractostrati
# fraena
# frauen
# frena
# frenula
# frescoes
# fricandeaux
# fricandoes
# frijoles
# frogfishes
# frontes
# frusta
# fuci
# fulcra
# fumatoria
# fundi
# fungi
# funiculi
# furcula
# furculae
# furfures
# galeae
# gambadoes
# gametangia
# gametoecia
# gammadia
# ganglia
# garfishes
# gas
# gasses
# gastrulae
# gateaux
# gazeboes
# geckoes
# geese
# gelsemia
# gemboks
# gembucks
# gemeinschaften
# gemmae
# genera
# generatrices
# geneses
# genii
# gentes
# gentlemen-at-arms
# gentlemen-farmers
# genua
# genus
# germina
# gesellschaften
# gestalten
# ghettoes
# gingivae
# gingkoes
# ginglymi
# ginkgoes
# gippoes
# glabellae
# gladioli
# glandes
# gliomata
# glissandi
# globefishes
# globigerinae
# glochidcia
# glochidia
# glomeruli
# glossae
# glottides
# glutaei
# glutei
# gnoses
# goatfishes
# goboes
# godchildren
# goes
# goings-over
# goldfishes
# gomphoses
# gonia
# gonidia
# gonococci
# goodwives
# goosefishes
# gorgoneia
# gospopoda
# governors_general
# goyim
# grafen
# graffiti
# grandchildren
# grants-in-aid
# granulomata
# gravamina
# grig-gris
# groszy
# grottoes
# guilder
# guilders
# guitarfishes
# gummata
# gurnard
# gurnards
# guttae
# gymnasia
# gynaecea
# gynaecia
# gynecea
# gynecia
# gynoecea
# gynoecia
# gyri
# hadarim
# hadjes
# haematolyses
# haematomata
# haematozoa
# haemodialyses
# haemolyses
# haemoptyses
# haeredes
# haftaroth
# hagfishes
# haggadas
# haggadoth
# hajjes
# haleru
# hallot
# halloth
# halluces
# haloes
# halteres
# halves
# hamuli
# hangers-on
# haphtaroth
# haredim
# haruspices
# hasidim
# hassidim
# haustella
# haustoria
# hazzanim
# hectocotyli
# heirs-at-law
# heldentenore
# helices
# heliozoa
# hematolyses
# hematomata
# hematozoa
# hemelytra
# hemielytra
# hemodialyses
# hemolyses
# hemoptyses
# hendecahedra
# hens-and-chickens
# heraclidae
# heraklidae
# herbaria
# hermae
# hermai
# herniae
# heroes
# herren
# hetaerae
# hetairai
# hibernacula
# hieracosphinges
# hila
# hili
# himatia
# hippocampi
# hippopotami
# his
# hoboes
# hogfishes
# homunculi
# honoraria
# hooves
# horologia
# housewives
# humeri
# hydrae
# hydromedusae
# hydrozoa
# hymenoptera
# hynia
# hyniums
# hypanthia
# hyperostoses
# hyphae
# hypnoses
# hypochondria
# hypogastria
# hypogea
# hypophyses
# hypostases
# hypothalami
# hypotheses
# hyraces
# iambi
# ibices
# ibo
# ichthyosauri
# ichthyosauruses
# iconostases
# icosahedra
# ideata
# igorrorote
# ilia
# imagines
# imagoes
# imperia
# impies
# incubi
# incudes
# indices
# indigoes
# indumenta
# indusia
# infundibula
# ingushes
# innuendoes
# inocula
# inquisitors-general
# insectaria
# insulae
# intagli
# interleaves
# intermezzi
# interreges
# interregna
# intimae
# involucella
# involucra
# involucra
# irides
# irs
# is
# ischia
# isthmi
# jackeroos
# jackfishes
# jackknives
# jacks-in-the-box
# jambeaux
# jellyfishes
# jewelfishes
# jewfishes
# jingoes
# jinn
# joes
# judge_advocates_general
# jura
# kaddishim
# kalmuck
# kalmucks
# katabases
# keeshonden
# kibbutzim
# killifishes
# kingfishes
# kings-of-arms
# knights_bachelor
# knights_bachelors
# knights_templar
# knights_templars
# knives
# kohlrabies
# kronen
# kroner
# kronur
# krooni
# kylikes
# labara
# labella
# labia
# labra
# lactobacilli
# lacunae
# lacunaria
# ladies-in-waiting
# lamellae
# lamiae
# laminae
# lapilli
# lapithae
# larvae
# larynges
# lassoes
# lati
# latices
# latifundia
# latu
# lavaboes
# leaves
# lecythi
# leges
# lei
# lemmata
# lemnisci
# lenes
# lentigines
# leonides
# lepidoptera
# leprosaria
# lepta
# leptocephali
# leucocytozoa
# leva
# librae
# libretti
# lice
# lieder
# ligulae
# limbi
# limina
# limites
# limuli
# lingoes
# linguae
# linguae_francae
# lionfishes
# lipomata
# lire
# liriodendra
# listente
# litai
# litu
# lives
# lixivia
# loaves
# loci
# loculi
# loggie
# logia
# lomenta
# longobardi
# loricae
# luba
# lubritoria
# lumbus
# lumina
# lumpfishes
# lungfishes
# lunulae
# lures
# lustra
# lyings-in
# lymphangitides
# lymphomata
# lymphopoieses
# lyses
# lyttae
# maare
# macaronies
# maccaronies
# machzorim
# macronuclei
# macrosporangia
# maculae
# madornos
# maestri
# mafiosi
# magi
# magmata
# magnificoes
# mahzorim
# major-axes
# major_axes
# makuta
# mallei
# malleoli
# maloti
# mamillae
# mammae
# mammillae
# mandingoes
# mangoes
# manifestoes
# manteaux
# mantes
# manubria
# marchese
# marchesi
# maremme
# markkaa
# marsupia
# marvels-of-peru
# mass_media
# masses
# masters-at-arms
# matrices
# matzoth
# mausolea
# maxillae
# maxima
# media
# mediae
# mediastina
# medullae
# medullae_oblongatae
# medusae
# megara
# megasporangia
# megilloth
# meioses
# melanomata
# melismata
# mementoes
# memoranda
# men
# men-at-arms
# men-o'-war
# men-of-war
# men_of_letters
# menisci
# menservants
# menstrua
# mesdames
# mesdemoiselles
# mesentera
# mesothoraces
# messeigneurs
# messieurs
# mestizoes
# metacarpi
# metamorphoses
# metanephroi
# metastases
# metatarsi
# metatheses
# metathoraces
# metazoa
# metempsychoses
# metencephala
# mezuzoth
# miasmata
# mice
# microanalyses
# micrococci
# micronuclei
# microsporangia
# midrashim
# midwives
# milia
# milieux
# militated_against
# milkfishes
# millennia
# minae
# minima
# ministeria
# minutiae
# minyanim
# mioses
# miracidia
# miri
# mishnayoth
# mitochondria
# mitzvoth
# modioli
# moduli
# momenta
# moments_of_truth
# momi
# monades
# monkfishes
# monochasia
# monopodia
# monoptera
# monopteroi
# monsignori
# monts-de-piete
# mooncalves
# moonfishes
# morae
# moratoria
# morceaux
# morescoes
# moriscoes
# morphallaxes
# morphoses
# morulae
# mosasauri
# moshavim
# moslim
# moslims
# mosquitoes
# mothers-in-law
# mothers_superior
# mottoes
# movers_and_shakers
# mucosae
# mucrones
# mudejares
# mudfishes
# mulattoes
# multiparae
# murices
# muskallunge
# mycelia
# mycetomata
# mycobacteria
# mycorrhizae
# myelencephala
# myiases
# myocardia
# myofibrillae
# myomata
# myoses
# myrmidones
# mythoi
# myxomata
# naevi
# naiades
# naoi
# narcissi
# nares
# nasopharynges
# natatoria
# naumachiae
# nauplii
# nautili
# navahoes
# navajoes
# nebulae
# necropoleis
# needlefishes
# negrilloes
# negritoes
# negroes
# nemeses
# nephridia
# nereides
# neurohypophyses
# neuromata
# neuroptera
# neuroses
# nevi
# nibelungen
# nidi
# nielli
# nilgai
# nimbi
# nimbostrati
# noctilucae
# nodi
# noes
# nomina
# nota
# noumena
# novae
# novelle
# novenae
# nubeculae
# nucelli
# nuchae
# nuclei
# nucleoli
# nulliparae
# numbfishes
# numina
# nymphae
# oarfishes
# oases
# obeli
# objets_d'art
# obligati
# oboli
# occipita
# oceanaria
# oceanides
# ocelli
# ochreae
# ocreae
# octahedra
# octopi
# oculi
# odea
# oedemata
# oesophagi
# oldwives
# olea
# omasa
# omayyades
# omenta
# ommatidia
# ommiades
# onagri
# oogonia
# oothecae
# operas_seria
# opercula
# optima
# ora
# organa
# organums
# orthoptera
# osar
# oscula
# ossa
# osteomata
# ostia
# ottomans
# ova
# ovoli
# ovotestes
# oxen
# oxymora
# paddlefishes
# paise
# paleae
# palestrae
# palingeneses
# pallia
# palmettoes
# palpi
# pancratia
# panettoni
# paparazzi
# paperknives
# papillae
# papillomata
# pappi
# papulae
# papyri
# parabases
# paraleipses
# paralyses
# paramecia
# paramenta
# paraphyses
# parapodia
# parapraxes
# paraselenae
# parashoth
# parasyntheta
# parazoa
# parentheses
# parerga
# parhelia
# parietes
# paris-mutuels
# parrotfishes
# parulides
# pasos_dobles
# passers-by
# pastorali
# patagia
# patellae
# patinae
# patresfamilias
# pease
# peccadilloes
# pectines
# pedaloes
# pedes
# pekingese
# pelves
# pence
# penes
# penetralium
# penicillia
# penknives
# pennae
# pennia
# pentahedra
# pentimenti
# penumbrae
# pepla
# pericardia
# perichondria
# pericrania
# peridia
# perigonia
# perihelia
# perinea
# perinephria
# perionychia
# periostea
# periphrases
# peristalses
# perithecia
# peritonea
# personae
# petechiae
# pfennige
# phalanges
# phalli
# pharynges
# phenomena
# phi-phenomena
# philodendra
# phlyctenae
# phyla
# phylae
# phyllotaxes
# phylloxerae
# phylogeneses
# pieds-a-terre
# pigfishes
# pilea
# pilei
# pineta
# pinfishes
# pinkoes
# pinnae
# pinnulae
# pipefishes
# pirogi
# piscinae
# pithecanthropi
# pithoi
# placeboes
# placentae
# planetaria
# planulae
# plasmodesmata
# plasmodia
# plateaux
# plectra
# plena
# pleura
# pleurae
# plicae
# ploughmen
# pneumobacilli
# pneumococci
# pocketknives
# podetia
# podia
# poleis
# pollices
# pollinia
# polychasia
# polyhedra
# polyparia
# polypi
# polyzoa
# polyzoaria
# pontes
# pontifices
# portamenti
# porticoes
# portmanteaux
# postliminia
# potatoes
# praenomina
# praxes
# predelle
# premaxillae
# prenomina
# prese
# primi
# primigravidae
# primiparae
# primordia
# principia
# proboscides
# proces-verbaux
# proglottides
# prognoses
# prolegomena
# prolepses
# promycelia
# pronephra
# pronephroi
# pronuclei
# propositi
# proptoses
# propyla
# propylaea
# proscenia
# prosencephala
# prostheses
# prostomia
# protases
# prothalamia
# prothalli
# prothallia
# prothoraces
# protonemata
# protozoa
# proventriculi
# provisoes
# prytanea
# psalteria
# pseudopodia
# psychoneuroses
# psychoses
# pterygia
# pterylae
# ptoses
# pubes
# pudenda
# puli
# pulvilli
# pulvini
# punchinelloes
# pupae
# puparia
# putamina
# putti
# pycnidia
# pygidia
# pylori
# pyxides
# pyxidia
# qaddishim
# quadrennia
# quadrigae
# qualia
# quanta
# quarterstaves
# quezales
# quinquennia
# quizzes
# rabatos
# rabbitfishes
# rachides
# radices
# radii
# radulae
# ramenta
# rami
# ranulae
# ranunculi
# raphae
# raphides
# ratfishes
# reales
# rearmice
# recta
# recti
# rectrices
# redfishes
# rediae
# referenda
# refugia
# reguli
# reis
# relata
# remiges
# reremice
# reseaux
# residua
# responsa
# retia
# retiarii
# reticula
# retinacula
# retinae
# rhabdomyomata
# rhachides
# rhachises
# rhinencephala
# rhizobia
# rhombi
# rhonchi
# rhyta
# ribbonfishes
# ricercacari
# ricercari
# rickettsiae
# rilievi
# rimae
# robes-de-chambre
# rockfishes
# roma
# romans-fleuves
# rondeaux
# rosaria
# rosefishes
# rostella
# rostra
# rouleaux
# rugae
# rumina
# runners-up
# sacra
# sacraria
# saguaros
# sailfishes
# salespeople
# salmonellae
# salpae
# salpinges
# saltarelli
# salvoes
# sancta
# sanitaria
# santimi
# saphenae
# sarcophagi
# sartorii
# sassanidae
# sawfishes
# scaldfishes
# scaleni
# scapulae
# scarabaei
# scarves
# schatchonim
# schemata
# scherzandi
# scherzi
# schmoes
# scholia
# schuln
# schutzstaffeln
# scirrhi
# scleromata
# scleroses
# sclerotia
# scoleces
# scolices
# scopulae
# scoriae
# scotomata
# scriptoria
# scrota
# scudi
# scuta
# scutella
# scyphi
# scyphistomae
# scyphozoa
# secondi
# secretaries-general
# segni
# seleucidae
# selves
# senores
# sensilla
# senti
# senussis
# separatrices
# sephardim
# septa
# septaria
# septennia
# sequelae
# sequestra
# sera
# seraphim
# sestertia
# setae
# sgraffiti
# shabbasim
# shabbatim
# shackoes
# shadchanim
# shadchans
# shakoes
# shammosim
# sheatfishes
# sheaves
# shellfishes
# shelves
# shinleaves
# shittim
# shmoes
# shofroth
# shophroth
# shrewmice
# shuln
# siddurim
# sigloi
# signore
# signori
# signorine
# siliquae
# silvae
# silverfishes
# simulacra
# sincipita
# sinfonie
# sisters-in-law
# sistra
# situlae
# smalti
# snaggleteeth
# snailfishes
# snipefishes
# socmen
# sola
# solaria
# solatia
# soldi
# soles
# solfeggi
# soli
# solidi
# somata
# sons-in-law
# soprani
# sordini
# sori
# soroses
# sovkhozy
# spadefishes
# spadices
# spearfishes
# spectra
# specula
# spermatia
# spermatogonia
# spermatozoa
# spermogonia
# sphinges
# spicae
# spicula
# spirilla
# splayfeet
# splenii
# sporangia
# sporogonia
# sporozoa
# springhase
# spumoni
# sputa
# squamae
# squashes
# squillae
# squirrelfishes
# squizzes
# stadia
# stamina
# staminodia
# stapedes
# staphylococci
# starfishes
# startsy
# stelae
# stemmata
# stenoses
# stepchildren
# sterna
# stigmata
# stimuli
# stipites
# stirpes
# stoae
# stockfishes
# stomata
# stomodaea
# stomodea
# stonefishes
# stotinki
# stotkini
# strappadoes
# strata
# strati
# stratocumuli
# street_children
# streptococci
# stretti
# striae
# strobili
# stromata
# strumae
# stuccoes
# styli
# stylopes
# stylopodia
# subcortices
# subdeliria
# subgenera
# subindices
# submucosae
# subphyla
# substrasta
# succedanea
# succubi
# suckerfishes
# suckfishes
# sudaria
# sudatoria
# sulci
# summae
# sunfishes
# supercargoes
# superheroes
# supernovae
# superstrata
# surgeonfishes
# swamies
# sweetiewives
# swellfishes
# swordfishes
# syconia
# syllabi
# syllepses
# symphyses
# sympodia
# symposia
# synapses
# synarthroses
# synclinoria
# syncytia
# syndesmoses
# synopses
# syntagmata
# syntheses
# syphilomata
# syringes
# syssarcoses
# tableaux
# taeniae
# tali
# tallaisim
# tallithes
# tallitoth
# tapeta
# tarantulae
# tarsi
# tarsometatarsi
# taxa
# taxes
# taxies
# tectrices
# teeth
# tegmina
# telae
# telamones
# telangiectases
# telia
# tempi
# tenacula
# tenderfeet
# teniae
# tenues
# teraphim
# terata
# teredines
# terga
# termini
# terraria
# terzetti
# tesserae
# testae
# testes
# testudines
# tetrahedra
# tetraskelia
# thalamencephala
# thalami
# thalli
# theatres-in-the-round
# thecae
# therses
# thesauri
# theses
# thickleaves
# thieves
# tholoi
# thoraces
# thrombi
# thymi
# thyrsi
# tibiae
# tilefishes
# tintinnabula
# titmice
# toadfishes
# tobaccoes
# tomatoes
# tomenta
# tondi
# tonneaux
# tophi
# topoi
# tori
# tornadoes
# torpedoes
# torsi
# touracos
# trabeculae
# tracheae
# traditores
# tragi
# trapezia
# trapezohedra
# traumata
# treponemata
# trichinae
# triclinia
# triennia
# triforia
# triggerfishes
# trihedra
# triskelia
# trisoctahedra
# triumviri
# trivia
# trochleae
# tropaeola
# trous-de-loup
# trousseaux
# trunkfishes
# trymata
# tubae
# turves
# tympana
# tyros
# ubermenschen
# uglies
# uigurs
# ulnae
# ultimata
# umbilici
# umbones
# umbrae
# unci
# uncidia
# uredines
# uredinia
# uredosori
# urethrae
# urinalyses
# uteri
# utriculi
# uvulae
# vacua
# vagi
# vaginae
# valleculae
# vaporetti
# varices
# vasa
# vascula
# vela
# velamina
# velaria
# venae
# venae_cavae
# ventriculi
# vermes
# verrucae
# vertebrae
# vertices
# vertigines
# vertigoes
# vesicae
# vetoes
# vexilla
# viatica
# viatores
# vibracula
# vibrissae
# vice-chairman
# villi
# vimina
# vincula
# viragoes
# vires
# virtuosi
# vitae
# vitelli
# vittae
# vivaria
# voces
# volcanoes
# volkslieder
# volte
# volvae
# vorticellae
# vortices
# vulvae
# wagons-lits
# wahhabis
# wanderjahre
# weakfishes
# werewolves
# wharves
# whippers-in
# whitefishes
# wives
# wolffishes
# wolves
# woodlice
# wreckfishes
# wunderkinder
# xiphisterna
# yeshivahs
# yeshivoth
# yogin
# yourselves
# zamindaris
# zecchini
# zeroes
# zoa
# zoaeae
# zoeae
# zoeas
# zoonoses
# zoosporangia
# adv.exc
# best
# better
# deeper
# farther
# further
# harder
# hardest

# %% [markdown]
# # Load the Repo

# %%
# %cd /content
# !git clone https://github.com/HaloKim/KorBertSum.git
# %cd /content/KorBertSum
# Out:
# /content
# Cloning into 'KorBertSum'...
# remote: Enumerating objects: 11187, done.
# remote: Counting objects: 100% (428/428), done.
# remote: Compressing objects: 100% (181/181), done.
# remote: Total 11187 (delta 250), reused 415 (delta 242), pack-reused 10759
# Receiving objects: 100% (11187/11187), 19.00 MiB | 16.19 MiB/s, done.
# Resolving deltas: 100% (3463/3463), done.
# /content/KorBertSum

# %% [markdown]
# # BERT

# %%
from transformers import BertTokenizer, BertModel, BertConfig

config = BertConfig.from_pretrained('bert-base-multilingual-cased')
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')
model = BertModel.from_pretrained("bert-base-multilingual-cased")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]

# %% [markdown]
# # Data Package

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json

with open('/content/drive/MyDrive/Colab Notebooks/news_sample.pkl', 'r') as json_file:
    json_list = list(json_file)
result = []
for json_str in json_list:
    result.append(json.loads(json_str))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-24-d74debf4a56b> in <cell line: 3>()
#       2
#       3 with open('/content/drive/MyDrive/Colab Notebooks/news_sample.pkl', 'r') as json_file:
# ----> 4     json_list = list(json_file)
#       5 result = []
#       6 for json_str in json_list:
#
# /usr/lib/python3.10/codecs.py in decode(self, input, final)
#     320         # decode input (taking the buffer into account)
#     321         data = self.buffer + input
# --> 322         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     323         # keep undecoded input until the next call
#     324         self.buffer = data[consumed:]
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte

# %%
import pandas as pd
df = pd.DataFrame(result)
df.head()
# Out:
#   media  ...  extractive
# 0  당진시대  ...   [0, 1, 2]
# 1  국제신문  ...   [0, 1, 3]
# 2  기호일보  ...  [6, 7, 10]
# 3  대구일보  ...   [1, 6, 4]
# 4  대구신문  ...  [2, 3, 10]
#
# [5 rows x 5 columns]

# %%
test = df

# %%
test = df
test['morphs'] = 0
for i in range(len(test)):
  arr = []
  for j in test['article_original'][i]:
    arr.append(' '.join(mecab.morphs(j)))
  test['morphs'][i] = arr
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
test.to_csv('/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/output.csv')

# %% [markdown]
# # Load csv

# %%
import pandas as pd
import json

test = pd.read_csv('/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/output.csv').drop('Unnamed: 0', axis=1)
test.head()
# Out:
#   media  ...                                             morphs
# 0  당진시대  ...  ['당진시 문화 관광 과 를 대상 으로 하 는 행정 사무 감사 에서 당진 시립 합창...
# 1  국제신문  ...  ['미국 메이저 리그 ( MLB ) 에서 활동 하 는 한국 선수 들 의 시즌 초반 ...
# 2  기호일보  ...  ['인천 부영 공원 운영 생활 야구 협회 80 여 동호회 팀 에 260 만 원 씩 ...
# 3  대구일보  ...  ['대구 · 경북 첨단 의료 산업 진흥 재단 의약 생산 센터 는 항암 주사제 무균 ...
# 4  대구신문  ...  ['국내 유통 되 는 탄산 음료 중 식품 의 약 품안 전처 에 품질 인증 을 받 은...
#
# [5 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(test, test_size = 0.2)
valid_set, test_set = train_test_split(test_set, test_size = 0.1)

# %% [markdown]
# # csv to json

# %%
import ast
from tqdm import tqdm
import os

list_dic = []
for idx, row in train_set.iterrows():
  raw = row['morphs']
  target_idx = ast.literal_eval(row['extractive'])

  sentences = raw.split(',')
  src = [i.split(' ') for i in sentences]
  tgt = [a for i,a in enumerate(src) if i in target_idx]

  mydict = {}
  mydict['src'] = src
  mydict['tgt'] = tgt
  list_dic.append(mydict)

temp = []
for i,a in enumerate(tqdm(list_dic)):
  if (i+1)%6!=0:
      temp.append(a)
  else:
      filename = 'korean.'+'train'+'.'+str(i//6)+'.json'
      with open('/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master'+'/json/'+filename, "w", encoding='utf-8') as json_file:
          json.dump(temp, json_file, ensure_ascii=False)
      temp = []
# Out:
#   0%|          | 0/34242 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-19-ccb4efe30393> in <module>()
#      23   else:
#      24       filename = 'korean.'+'train'+'.'+str(i//6)+'.json'
# ---> 25       with open('/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master'+'/json/'+filename, "w", encoding='utf-8') as json_file:
#      26           json.dump(temp, json_file, ensure_ascii=False)
#      27       temp = []
#
# OSError: [Errno 5] Input/output error: '/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/json/korean.train.0.json'

# %%
try:
  os.mkdir('/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/json/val')
except:
  pass

list_dic = []
for idx, row in valid_set.iterrows():
        raw = row['morphs']
        target_idx = ast.literal_eval(row['extractive'])

        sentences = raw.split(',')
        src = [i.split(' ') for i in sentences]
        tgt = [a for i,a in enumerate(src) if i in target_idx]

        mydict = {}
        mydict['src'] = src
        mydict['tgt'] = tgt
        list_dic.append(mydict)

temp = []
for i,a in enumerate(tqdm(list_dic)):

    if (i+1)%6!=0:
        temp.append(a)
    else:
        filename = 'korean.'+'valid'+'.'+str(i//6)+'.json'
        with open('/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master'+'/json/val/'+filename, "w", encoding='utf-8') as json_file:
            json.dump(temp, json_file, ensure_ascii=False)
        temp = []

# %%
try:
  os.mkdir('/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/json/test')
except:
  pass

list_dic = []
for idx, row in valid_set.iterrows():
        raw = row['morphs']
        target_idx = ast.literal_eval(row['extractive'])

        sentences = raw.split(',')
        src = [i.split(' ') for i in sentences]
        tgt = [a for i,a in enumerate(src) if i in target_idx]

        mydict = {}
        mydict['src'] = src
        mydict['tgt'] = tgt
        list_dic.append(mydict)

temp = []
for i,a in enumerate(tqdm(list_dic)):

    if (i+1)%6!=0:
        temp.append(a)
    else:
        filename = 'korean.'+'test'+'.'+str(i//6)+'.json'
        with open('/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master'+'/json/val/'+filename, "w", encoding='utf-8') as json_file:
            json.dump(temp, json_file, ensure_ascii=False)
        temp = []

# %% [markdown]
# # Json to pt

# %%
# 데이터 처리모드, json경로, 저장경로, 로그파일
# !python /content/KorBertSum/src/preprocess.py \
  -mode format_to_bert \
  -raw_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/json \
  -save_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/bert_data \
  -dataset train \

# %%
try:
  os.mkdir('/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/bert_data/val')
except:
  pass

# !python /content/KorBertSum/src/preprocess.py \
  -mode format_to_bert \
  -raw_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/json/val \
  -save_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/bert_data/test \
  -dataset valid \

# %%
try:
  os.mkdir('/content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/bert_data/test')
except:
  pass

# !python /content/KorBertSum/src/preprocess.py \
  -mode format_to_bert \
  -raw_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/json/test \
  -save_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/bert_data/test \
  -dataset test \

# %% [markdown]
# # Train

# %%
# !python /content/KorBertSum/src/train.py \
  -mode train \
  -encoder classifier \
  -bert_data_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/bert_data/korean \
  -model_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/models/bert_classifier \
  -log_file /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/logs/train.txt \
  -lr 2e-3 -visible_gpus 0 -gpu_ranks 0 -world_size 1 -report_every 1000 -dropout 0.5 \
  -save_checkpoint_steps 1000 -batch_size 3000 -decay_method noam -train_steps 100000 -accum_count 1\

# %% [markdown]
# # Validation

# %%
# %cd /content

# !python /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/src/train.py \
  -mode validate \
  -bert_data_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/bert_data/test/korean \
  -visible_gpus 0 -gpu_ranks 0 -batch_size 3000 \
  -log_file /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/logs/val.txt \
  -temp_dir /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/temp \
  -result_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/results \
  -test_from /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/models/bert_classifier/model_step_9000.pt \

# %% [markdown]
# # Test

# %%
# %cd /content

# !python /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/src/train.py \
  -mode test \
  -bert_data_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/bert_data/test/korean \
  -visible_gpus 0 -gpu_ranks 0 -batch_size 3000 \
  -log_file /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/logs/val.txt \
  -temp_dir /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/temp \
  -result_path /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/results \
  -test_from /content/drive/MyDrive/Colab_Notebooks/Study/BertSum-master/models/bert_classifier/model_step_21000.pt \
